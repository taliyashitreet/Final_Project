# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2023-07-17 17:17:07.603220: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def clean_gene(df, column):
    # Copy the dataframe to avoid modifying the original
    df = df.copy()

    # Replace hyphen '-' and '(' ')' with nothing
    df[column] = df[column].str.replace(r'[-\(\)\'\?\_]', '', regex=True)

    # Convert all upper case to lower case
    df[column] = df[column].str.lower()

    return df

# %%
val_data = pd.read_csv("Referece_gene_catalogue_resistance_amr_validation.csv")
val_data.head(10)
# Out:
#    Gene family           Class               Subclass
# 0   aac(2')-Ia  AMINOGLYCOSIDE  GENTAMICIN/TOBRAMCYIN
# 1   aac(2')-Ib  AMINOGLYCOSIDE  GENTAMICIN/TOBRAMCYIN
# 2   aac(2')-Ic  AMINOGLYCOSIDE  GENTAMICIN/TOBRAMCYIN
# 3   aac(2')-Id  AMINOGLYCOSIDE  GENTAMICIN/TOBRAMCYIN
# 4   aac(2')-Ie  AMINOGLYCOSIDE  GENTAMICIN/TOBRAMCYIN
# 5  aac(2')-IIa  AMINOGLYCOSIDE            KASUGAMYCIN
# 6  aac(2')-IIb  AMINOGLYCOSIDE            KASUGAMYCIN
# 7     aac(3)-I  AMINOGLYCOSIDE             GENTAMICIN
# 8     aac(3)-I  AMINOGLYCOSIDE             GENTAMICIN
# 9     aac(3)-I  AMINOGLYCOSIDE             GENTAMICIN

# %%
val_data.drop('Class', axis=1, inplace=True)
val_data.drop_duplicates(inplace=True)
val_data['Subclass'] = val_data['Subclass'].str.lower()
val_data['Subclass'] = val_data['Subclass'].str.split('/')
val_data = val_data.explode('Subclass')
val_data['Gene family'] = val_data['Gene family'].str.split('/')
val_data = val_data.explode('Gene family')
val_data.drop_duplicates(inplace=True)
val_data.dropna(inplace=True)
val_data = val_data.reset_index()
val_data = clean_gene(val_data,'Gene family')
val_data
# Out:
#       index Gene family       Subclass
# 0         0      aac2ia     gentamicin
# 1         0      aac2ia     tobramcyin
# 2         1      aac2ib     gentamicin
# 3         1      aac2ib     tobramcyin
# 4         2      aac2ic     gentamicin
# ...     ...         ...            ...
# 1247   6668        vmlr    lincosamide
# 1248   6668        vmlr  streptogramin
# 1249   6668        vmlr       tiamulin
# 1250   6669         vph       viomycin
# 1251   6671        zbma     zorbamycin
#
# [1252 rows x 3 columns]

# %%
val_data.to_csv("val_data.csv", index=False)

# %%
data = pd.read_csv(r'isolates.csv')
data.head(10)
# Out:
#           #Organism group         Isolate  \
# 0  Listeria monocytogenes  PDT000077416.3
# 1  Listeria monocytogenes  PDT000095192.3
# 2     Salmonella enterica  PDT000003687.3
# 3     Salmonella enterica  PDT000003688.4
# 4     Salmonella enterica  PDT000003689.4
# 5     Salmonella enterica  PDT000003690.3
# 6     Salmonella enterica  PDT000003691.3
# 7     Salmonella enterica  PDT000003692.3
# 8     Salmonella enterica  PDT000003693.3
# 9     Salmonella enterica  PDT000003694.4
#
#                                        AMR genotypes  \
# 0                         fosX=COMPLETE,lin=COMPLETE
# 1                         fosX=COMPLETE,lin=COMPLETE
# 2                        mdsA=COMPLETE,mdsB=COMPLETE
# 3                        mdsA=COMPLETE,mdsB=COMPLETE
# 4                        mdsA=COMPLETE,mdsB=COMPLETE
# 5  aph(3'')-Ib=COMPLETE,aph(6)-Id=COMPLETE,mdsA=C...
# 6        mdsA=COMPLETE,mdsB=COMPLETE,tet(B)=COMPLETE
# 7                        mdsA=COMPLETE,mdsB=COMPLETE
# 8  aph(3'')-Ib=COMPLETE,aph(6)-Id=COMPLETE,mdsA=C...
# 9         fosA7=COMPLETE,mdsA=COMPLETE,mdsB=COMPLETE
#
#                                       AST phenotypes
# 0  chloramphenicol=S,clindamycin=R,erythromycin=S...
# 1                          ampicillin=S,penicillin=S
# 2  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 3  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 4  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 5  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 6  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 7  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 8  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 9  amikacin=S,amoxicillin-clavulanic acid=S,ampic...

# %%
anti_family = pd.read_csv("gene_anti_family.csv")
anti_family.head(10)
# Out:
# /var/folders/jp/2wr1hx0s4zjdcnf63gtk75fw0000gq/T/ipykernel_67583/3043385186.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   anti_family = pd.read_csv("gene_anti_family.csv")
#   gene family         gene                     antibiotic      drug_class  \
# 0    ANT(2'')  ANT(2'')-Ia                  spectinomycin  aminoglycoside
# 1    ANT(2'')  ANT(2'')-Ia  trimethoprim-sulfamethoxazole     sulfonamide
# 2    ANT(2'')  ANT(2'')-Ia                   azithromycin       macrolide
# 3    ANT(2'')  ANT(2'')-Ia          ceftazidime-avibactam  beta-lactamase
# 4    ANT(2'')  ANT(2'')-Ia                   piperacillin      Penicillin
# 5    ANT(2'')  ANT(2'')-Ia                    ticarcillin      Penicillin
# 6    ANT(2'')  ANT(2'')-Ia                      kanamycin  Aminoglycoside
# 7    ANT(2'')  ANT(2'')-Ia                      oxacillin      Penicillin
# 8    ANT(2'')  ANT(2'')-Ia                      tedizolid   Oxazolidinone
# 9    ANT(2'')  ANT(2'')-Ia                    cefiderocol  beta-lactamase
#
#      S    R
# 0  NaN  1.0
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
# 5  NaN  NaN
# 6  NaN  1.0
# 7  NaN  NaN
# 8  NaN  NaN
# 9  NaN  NaN

# %%
anti_family = clean_gene(anti_family,'gene')
anti_family
# Out:
#        gene family    gene                     antibiotic      drug_class  \
# 0         ANT(2'')  ant2ia                  spectinomycin  aminoglycoside
# 1         ANT(2'')  ant2ia  trimethoprim-sulfamethoxazole     sulfonamide
# 2         ANT(2'')  ant2ia                   azithromycin       macrolide
# 3         ANT(2'')  ant2ia          ceftazidime-avibactam  beta-lactamase
# 4         ANT(2'')  ant2ia                   piperacillin      Penicillin
# ...            ...     ...                            ...             ...
# 264379         NaN  mcr2.3                    ceftazidime  beta-lactamase
# 264380         NaN  mcr2.3    amoxicillin-clavulanic acid  beta-lactamase
# 264381         NaN  mcr2.3                   streptomycin  Aminoglycoside
# 264382         NaN  mcr2.3                   moxifloxacin       Quinolone
# 264383         NaN  mcr2.3                  metronidazole      nitrofuran
#
#           S    R
# 0       NaN  1.0
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# 4       NaN  NaN
# ...     ...  ...
# 264379  NaN  NaN
# 264380  NaN  NaN
# 264381  NaN  NaN
# 264382  NaN  NaN
# 264383  NaN  NaN
#
# [264384 rows x 6 columns]

# %%
def transform_dataframe(df):
    new_data = []

    for idx, row in df.iterrows():
        # split AMR genotypes and remove "=COMPLETE"
        amr_genotypes = [i.split('=')[0] for i in row['AMR genotypes'].split(',')]

        # split AST phenotypes
        ast_phenotypes = row['AST phenotypes'].split(',')

        # process each phenotype
        for pheno in ast_phenotypes:
            drug, resistance = pheno.split('=')
            if resistance == 'R':
                resistance_score = 1
            elif resistance == 'S':
                resistance_score = 0
            else:  # assuming 'I' as per your description
                resistance_score = 0.5

            # create a new row
            new_row = {'#Organism group': row['#Organism group'],
                       'Isolate': row['Isolate'],
                       'AMR genotypes': ', '.join(amr_genotypes),
                       'drug': drug,
                       'resistance': resistance_score}
            new_data.append(new_row)

    # create a new dataframe
    new_df = pd.DataFrame(new_data)

    return new_df

# %%
df = transform_dataframe(data)

# %%
df.to_csv("BasicData.csv",index=False)
df.head(10)
# Out:
#           #Organism group         Isolate AMR genotypes  \
# 0  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 1  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 2  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 3  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 4  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 5  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 6  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 7  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 8  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 9  Listeria monocytogenes  PDT000077416.3     fosX, lin
#
#                             drug  resistance
# 0                chloramphenicol         0.0
# 1                    clindamycin         1.0
# 2                   erythromycin         0.0
# 3                     gentamicin         0.0
# 4                   levofloxacin         0.0
# 5                      oxacillin         1.0
# 6                     penicillin         0.0
# 7                       rifampin         0.0
# 8                   tetracycline         0.0
# 9  trimethoprim-sulfamethoxazole         0.0

# %%
df = clean_gene(df, 'AMR genotypes')
df
# Out:
#                   #Organism group         Isolate  \
# 0          Listeria monocytogenes  PDT000077416.3
# 1          Listeria monocytogenes  PDT000077416.3
# 2          Listeria monocytogenes  PDT000077416.3
# 3          Listeria monocytogenes  PDT000077416.3
# 4          Listeria monocytogenes  PDT000077416.3
# ...                           ...             ...
# 316066  Enterobacter roggenkampii  PDT000898827.2
# 316067  Enterobacter roggenkampii  PDT000898827.2
# 316068  Enterobacter roggenkampii  PDT001161812.2
# 316069  Enterobacter roggenkampii  PDT001161812.2
# 316070  Enterobacter roggenkampii  PDT001161812.2
#
#                                   AMR genotypes  \
# 0                                     fosx, lin
# 1                                     fosx, lin
# 2                                     fosx, lin
# 3                                     fosx, lin
# 4                                     fosx, lin
# ...                                         ...
# 316066  blamir, cata, fosa, mcr10.1, oqxa, oqxb
# 316067  blamir, cata, fosa, mcr10.1, oqxa, oqxb
# 316068               blamir16, cata, fosa, oqxb
# 316069               blamir16, cata, fosa, oqxb
# 316070               blamir16, cata, fosa, oqxb
#
#                                  drug  resistance
# 0                     chloramphenicol         0.0
# 1                         clindamycin         1.0
# 2                        erythromycin         0.0
# 3                          gentamicin         0.0
# 4                        levofloxacin         0.0
# ...                               ...         ...
# 316066                   tetracycline         0.0
# 316067  trimethoprim-sulfamethoxazole         0.0
# 316068                      ertapenem         0.0
# 316069                       imipenem         0.5
# 316070                      meropenem         0.0
#
# [316071 rows x 5 columns]

# %%
df.to_csv("BasicData_clean.csv",index=False)

# %%
def create_empty_gene_antibiotic_df(df,unique_all_genes,unique_all_antibiotics):
    for idx, row in df.iterrows():
        genotypes = row['AMR genotypes'].split(', ')
        antibiotic = row['drug']

        unique_all_genes.extend(genotypes)
        unique_all_antibiotics.append(antibiotic)

    unique_all_genes = list(set(unique_all_genes))  # Convert to list
    unique_all_antibiotics = list(set(unique_all_antibiotics))  # Convert to list

    gene_antibiotic_df = pd.DataFrame(index=unique_all_genes, columns=unique_all_antibiotics)
    gene_antibiotic_df = gene_antibiotic_df.fillna(-1)

    return gene_antibiotic_df

# Assuming your DataFrame is named 'new_dataframe'
unique_all_genes = []
unique_all_antibiotics = []
gene_antibiotic_df = create_empty_gene_antibiotic_df(df,unique_all_genes,unique_all_antibiotics)
gene_antibiotic_df
# Out:
#            ceftizoxime  oxytetracycline  cefpodoxime  cefamandole  \
# qnrb10              -1               -1           -1           -1
# cml                 -1               -1           -1           -1
# blaoxy26            -1               -1           -1           -1
# blaadc159           -1               -1           -1           -1
# blalen9             -1               -1           -1           -1
# ...                ...              ...          ...          ...
# blaoxa129           -1               -1           -1           -1
# lin                 -1               -1           -1           -1
# blaoxa64            -1               -1           -1           -1
# blaokpb3            -1               -1           -1           -1
# blactxm8            -1               -1           -1           -1
#
#            piperacillin  mecillinam  ticarcillin-clavulanic acid  \
# qnrb10               -1          -1                           -1
# cml                  -1          -1                           -1
# blaoxy26             -1          -1                           -1
# blaadc159            -1          -1                           -1
# blalen9              -1          -1                           -1
# ...                 ...         ...                          ...
# blaoxa129            -1          -1                           -1
# lin                  -1          -1                           -1
# blaoxa64             -1          -1                           -1
# blaokpb3             -1          -1                           -1
# blactxm8             -1          -1                           -1
#
#            nalidixic acid  cefazolin  gentamicin  ...  linezolid  \
# qnrb10                 -1         -1          -1  ...         -1
# cml                    -1         -1          -1  ...         -1
# blaoxy26               -1         -1          -1  ...         -1
# blaadc159              -1         -1          -1  ...         -1
# blalen9                -1         -1          -1  ...         -1
# ...                   ...        ...         ...  ...        ...
# blaoxa129              -1         -1          -1  ...         -1
# lin                    -1         -1          -1  ...         -1
# blaoxa64               -1         -1          -1  ...         -1
# blaokpb3               -1         -1          -1  ...         -1
# blactxm8               -1         -1          -1  ...         -1
#
#            meropenem-vaborbactam  ertapenem  ceftazidime-avibactam  \
# qnrb10                        -1         -1                     -1
# cml                           -1         -1                     -1
# blaoxy26                      -1         -1                     -1
# blaadc159                     -1         -1                     -1
# blalen9                       -1         -1                     -1
# ...                          ...        ...                    ...
# blaoxa129                     -1         -1                     -1
# lin                           -1         -1                     -1
# blaoxa64                      -1         -1                     -1
# blaokpb3                      -1         -1                     -1
# blactxm8                      -1         -1                     -1
#
#            trimethoprim-sulfamethoxazole  florfenicol  chlortetracycline  \
# qnrb10                                -1           -1                 -1
# cml                                   -1           -1                 -1
# blaoxy26                              -1           -1                 -1
# blaadc159                             -1           -1                 -1
# blalen9                               -1           -1                 -1
# ...                                  ...          ...                ...
# blaoxa129                             -1           -1                 -1
# lin                                   -1           -1                 -1
# blaoxa64                              -1           -1                 -1
# blaokpb3                              -1           -1                 -1
# blactxm8                              -1           -1                 -1
#
#            benzylpenicillin  doxycycline  norfloxacin
# qnrb10                   -1           -1           -1
# cml                      -1           -1           -1
# blaoxy26                 -1           -1           -1
# blaadc159                -1           -1           -1
# blalen9                  -1           -1           -1
# ...                     ...          ...          ...
# blaoxa129                -1           -1           -1
# lin                      -1           -1           -1
# blaoxa64                 -1           -1           -1
# blaokpb3                 -1           -1           -1
# blactxm8                 -1           -1           -1
#
# [1209 rows x 114 columns]

# %%
gene_antibiotic_df.to_csv("Empty_Gene_Antibiotic.csv", index=True, index_label=False)

# %% [markdown]
# ***********************************************

# %% [markdown]
# ### run from here

# %%
# def gene_per_drug(drug):
#     drug_df = df[df['drug'] == drug]
#     unique_genes = set()
#     for genes in drug_df['AMR genotypes'].str.split(', '):
#         unique_genes.update(genes)
#     return drug_df, unique_genes

# %%
df = pd.read_csv('BasicData_clean.csv')
val_data = pd.read_csv('val_data.csv')
gene_antibiotic_df = pd.read_csv('Empty_Gene_Antibiotic.csv')
anti_family = clean_gene(anti_family,'gene')

# %%
gene_antibiotic_df
# Out:
#             ticarcillin  ceftizoxime  netilmicin  ceftazidime  tobramycin  \
# 50sl22g86e           -1           -1          -1           -1          -1
# blaadc99             -1           -1          -1           -1          -1
# blaact70             -1           -1          -1           -1          -1
# blatem214            -1           -1          -1           -1          -1
# blaoxy27             -1           -1          -1           -1          -1
# ...                 ...          ...         ...          ...         ...
# mefh                 -1           -1          -1           -1          -1
# blaadc216            -1           -1          -1           -1          -1
# blaoxa421            -1           -1          -1           -1          -1
# blaoxa374            -1           -1          -1           -1          -1
# ampc                 -1           -1          -1           -1          -1
#
#             meropenem  levofloxacin  amoxicillin-clavulanic acid  polymyxin B  \
# 50sl22g86e         -1            -1                           -1           -1
# blaadc99           -1            -1                           -1           -1
# blaact70           -1            -1                           -1           -1
# blatem214          -1            -1                           -1           -1
# blaoxy27           -1            -1                           -1           -1
# ...               ...           ...                          ...          ...
# mefh               -1            -1                           -1           -1
# blaadc216          -1            -1                           -1           -1
# blaoxa421          -1            -1                           -1           -1
# blaoxa374          -1            -1                           -1           -1
# ampc               -1            -1                           -1           -1
#
#             benzylpenicillin  ...  colistin  amoxicillin  spectinomycin  \
# 50sl22g86e                -1  ...        -1           -1             -1
# blaadc99                  -1  ...        -1           -1             -1
# blaact70                  -1  ...        -1           -1             -1
# blatem214                 -1  ...        -1           -1             -1
# blaoxy27                  -1  ...        -1           -1             -1
# ...                      ...  ...       ...          ...            ...
# mefh                      -1  ...        -1           -1             -1
# blaadc216                 -1  ...        -1           -1             -1
# blaoxa421                 -1  ...        -1           -1             -1
# blaoxa374                 -1  ...        -1           -1             -1
# ampc                      -1  ...        -1           -1             -1
#
#             oxacillin  cefotetan  plazomicin  enrofloxacin  doripenem  \
# 50sl22g86e         -1         -1          -1            -1         -1
# blaadc99           -1         -1          -1            -1         -1
# blaact70           -1         -1          -1            -1         -1
# blatem214          -1         -1          -1            -1         -1
# blaoxy27           -1         -1          -1            -1         -1
# ...               ...        ...         ...           ...        ...
# mefh               -1         -1          -1            -1         -1
# blaadc216          -1         -1          -1            -1         -1
# blaoxa421          -1         -1          -1            -1         -1
# blaoxa374          -1         -1          -1            -1         -1
# ampc               -1         -1          -1            -1         -1
#
#             cefalexin  nitrofurantoin
# 50sl22g86e         -1              -1
# blaadc99           -1              -1
# blaact70           -1              -1
# blatem214          -1              -1
# blaoxy27           -1              -1
# ...               ...             ...
# mefh               -1              -1
# blaadc216          -1              -1
# blaoxa421          -1              -1
# blaoxa374          -1              -1
# ampc               -1              -1
#
# [1209 rows x 114 columns]

# %%
def gene_per_drug(drug):
    drug_df = df[df['drug'] == drug]
    unique_genes = set()
    for genes in drug_df['AMR genotypes'].str.split(', '):
        unique_genes.update(genes)

    # Get unique #Organism group values
    organism_groups = drug_df['#Organism group'].unique()

    # Initialize empty lists for train_df and test_df
    train_dfs = []
    test_dfs = []

    # Iterate over #Organism groups
    for group in organism_groups:
        group_df = drug_df[drug_df['#Organism group'] == group]

        if len(group_df) > 1:
            group_train_df, group_test_df = train_test_split(group_df, test_size=0.2, random_state=42)
        else:
            group_train_df = group_df
            group_test_df = group_df

        train_dfs.append(group_train_df)
        test_dfs.append(group_test_df)

    # Concatenate the train and test dataframes for all groups
    train_df = pd.concat(train_dfs)
    test_df = pd.concat(test_dfs)

    return train_df, test_df, unique_genes

# Rest of the code remains the same

# %%
def relevant_val_df(drug,unique_genes):
    relevant_df = val_data[(val_data['Subclass'] == drug) & (val_data['Gene family'].isin(unique_genes))]
    if relevant_df.shape[0]>1 :
        val_train, val_test = train_test_split(relevant_df, test_size=0.2, random_state=42)
        return val_train, val_test
    return None, None

# %%
# def create_gene_df(drug_df,val_df, unique_genes):
#     gene_arrays = []
#     labels = []
#
#     for idx, row in drug_df.iterrows():
#         gene_array = np.zeros(len(unique_genes), dtype=int)
#         genes = row['AMR genotypes'].split(', ')
#         for gene in genes:
#             gene_index = list(unique_genes).index(gene)
#             gene_array[gene_index] = 1
#
#         gene_arrays.append(gene_array.tolist())
#         labels.append(row['resistance'])
#
#     gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
#     gene_df['label'] = labels
#
#     if val_df is not None:
#         for idx, row in val_df.iterrows():
#             gene_array = np.zeros(len(unique_genes), dtype=int)
#             gene = row['Gene family']
#             gene_index = list(unique_genes).index(gene)
#             gene_array[gene_index] = 1
#
#             gene_arrays.append(gene_array.tolist())
#             labels.append(1)
#
#         gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
#         gene_df['label'] = labels
#
#     return gene_df.sample(frac=1).reset_index(drop=True)

# %%
def create_update_gene_df(drug_df, val_df, unique_genes, drug, zero_col):
    gene_arrays = []
    labels = []
    drug_r = set(anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist())
    for _, row in drug_df.iterrows():
        genes = row['AMR genotypes'].split(', ')
        label = row['resistance']
        gene_array = np.zeros(len(unique_genes), dtype=int)

        for gene in genes:
            gene_index = list(unique_genes).index(gene)
            if gene in drug_r:
                gene_array[gene_index] = 1

        gene_arrays.append(gene_array.tolist())
        labels.append(label)

    gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
    gene_df['label'] = labels

    if val_df is not None:
        for idx, row in val_df.iterrows():
            gene_array = np.zeros(len(unique_genes), dtype=int)
            gene = row['Gene family']
            gene_index = list(unique_genes).index(gene)
            gene_array[gene_index] = 1

            gene_arrays.append(gene_array.tolist())
            labels.append(1)

        gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
        gene_df['label'] = labels


    if len(zero_col) == 0:
        zero_col = [col for col in gene_df.columns if col not in drug_r and col != 'label']
    else:
        zero_col = [col for col in zero_col if col not in drug_r and col != 'label']
    gene_df = gene_df.drop(zero_col, axis=1)

    return gene_df.sample(frac=1).reset_index(drop=True), zero_col

# %%
# def update_df(df, drug, anti_family, zero_col):
#     # Get the list of genes for which the antibiotic is the specified drug
#     drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
#     drug_s = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] != 1) & (anti_family['S'] == 's'), 'gene'].tolist()
#
#     # Iterate over each row
#     for index, row in df.iterrows():
#         # Iterate over each column
#         for column in df.columns:
#             gene = str(column)
#             if gene == "label":
#                 continue
#             # Check if the gene is not in the list of drug genes and label is 1 or 0.5
#             if ((gene not in drug_r) or (gene in drug_s)) and (row['label'] == 1):
#                 # Set the value to 0 if the condition is met
#                 df.loc[index, column] = 0
#
#             # Check if the gene is in the list of drug genes and label is 0
#             if (gene in drug_r) and (row['label'] == 0):
#                 df.loc[index, column] = 0
#
#             if (gene in drug_s) and (row['label'] == 0):
#                 df.loc[index, column] = 1
#
#
#
#     if len(zero_col)==0:
#         zero_col = df.columns[df.eq(0).all(axis=0)]
#     df = df.drop(zero_col, axis=1)
#     return df, zero_col

# %%
def Model_deep(drug_train_for_model, drug_test_for_model, epochs, batch_size):
    # Assuming your DataFrame with gene features and labels is named `oxacillin_df_for_model`
    # Split the data into training features (genes) and labels
    X_train = drug_train_for_model.drop('label', axis=1).values
    y_train = drug_train_for_model['label'].values

    # Split the data into testing features (genes) and labels
    X_test = drug_test_for_model.drop('label', axis=1).values
    y_test = drug_test_for_model['label'].values

    # Define the neural network model
    model = keras.Sequential()
    model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dense(16, activation='relu'))
    model.add(keras.layers.Dense(1, activation='sigmoid'))  # Sigmoid activation for probability between 0 and 1

    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['mse'])

    # Train the model
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

    # Evaluate the model
    loss, mse = model.evaluate(X_test, y_test)
    pred = model.predict(X_test)
    print('Loss:', loss)
    print('Mean Squared Error:', mse)
    print('len of pred:', pred.shape, 'y_test:', y_test.shape)

    # Make predictions
    return y_test, pred, model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

def Model(drug_train_for_model, drug_test_for_model):
    # Split the data into training features (genes) and labels
    X_train = drug_train_for_model.drop('label', axis=1).values
    y_train = drug_train_for_model['label'].values

    # Split the data into testing features (genes) and labels
    X_test = drug_test_for_model.drop('label', axis=1).values
    y_test = drug_test_for_model['label'].values

    # Initialize the model
    model = RandomForestRegressor(n_estimators=100, random_state=0)

    # Train the model
    model.fit(X_train, y_train)

    # Predict the resistance score
    y_pred = model.predict(X_test)

    # Compute mean squared error
    mse = mean_squared_error(y_test, y_pred)

    print('Mean Squared Error:', mse)
    print('len of pred:', y_pred.shape, 'y_test:', y_test.shape)

    # Make predictions
    return y_test, y_pred, model

# %%
def evaluation(y_test, predictions, drug):
    # Calculate mean squared error
    mse = mean_squared_error(y_test, predictions)

    # Calculate mean absolute error
    mae = mean_absolute_error(y_test, predictions)

    # Calculate R^2 score
    r2 = r2_score(y_test, predictions)

    
    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('R^2 Score:', r2)
    return mse, mae, r2

# %%
def Create_df_one_gene(drug_df_for_model):
    # Extract the column names (excluding the label column)
    column_names = drug_df_for_model.columns[:-1]

    # Create a new DataFrame with zeros
    df_one_gene = pd.DataFrame(0, index=np.arange(len(column_names)), columns=column_names)

    # Set the value at the corresponding index position in each row
    for i in range(len(column_names)):
        df_one_gene.iloc[i, i] = 1

    # Display the new DataFrame
    return df_one_gene

# %%
# it will save the drugs with empty df_gene
problematic_drugs = []

# %%
def PredR_Antibiotic(drug):
    print('************************\n', drug)
    zero_lst = []
    drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
    train_df, test_df,drug_genes =   gene_per_drug(drug)
    val_train, val_test= relevant_val_df(drug, drug_genes)
    drug_train_for_model, zero_lst = create_update_gene_df(train_df, val_train, list(drug_genes), drug, zero_lst)
    drug_test_for_model, zero_lst = create_update_gene_df(test_df, val_test, list(drug_genes), drug, zero_lst)
    # Combine train and test dataframes
    combined_df = pd.concat([drug_train_for_model, drug_test_for_model], ignore_index=True)

    y_test, predictions, model = Model_deep(drug_train_for_model, drug_test_for_model, 40, 10)
    mse, mae, r2 = evaluation(y_test, predictions, drug)
    df_gene = Create_df_one_gene(combined_df)
    if df_gene.shape[1]>1:
     pred = model.predict(df_gene)
    else:
        problematic_drugs.append(drug)

    for col in drug_genes:
        if (df_gene.shape[1]>1) and (col in drug_r):
         gene_antibiotic_df.loc[col, drug] = pred[df_gene.columns.get_loc(col)]
        else:
          gene_antibiotic_df.loc[col, drug] = 0.0

# %%
# print('************************\n', 'amoxicillin-clavulanic acid')
# drug = 'amoxicillin-clavulanic acid'
# drug_s = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] != 1) & (anti_family['S'] == 'S'), 'gene'].tolist()
# drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
# zero_lst = []
# train_df, test_df,drug_genes =   gene_per_drug(drug)
# val_train, val_test= relevant_val_df(drug, drug_genes)
# drug_train_for_model, zero_lst= create_update_gene_df(train_df, val_train, list(drug_genes), drug, zero_lst)
# drug_test_for_model, zero_lst= create_update_gene_df(test_df, val_test, list(drug_genes), drug, zero_lst)
#
# combined_df = pd.concat([drug_train_for_model, drug_test_for_model], ignore_index=True)
#
# y_test, predictions, model = Model_deep(drug_train_for_model, drug_test_for_model,30,10)
# mse, mae, r2 = evaluation(y_test, predictions, drug)
# df_gene = Create_df_one_gene(combined_df)
# if df_gene.shape[1]>1:
#  pred = model.predict(df_gene)
#
# for col in drug_genes:
#     if ( df_gene.shape[1] >1) and (col in drug_r):
#      gene_antibiotic_df.loc[col, drug] = pred[df_gene.columns.get_loc(col)]
#     else:
#      gene_antibiotic_df.loc[col, drug] = 0.0

# %%
# print('************************\n', 'ciprofloxacin')
# drug = 'ciprofloxacin'
# drug_s = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] != 1) & (anti_family['S'] == 'S'), 'gene'].tolist()
# drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
# zero_lst = []
# train_df, test_df,drug_genes =   gene_per_drug(drug)
# val_train, val_test= relevant_val_df(drug, drug_genes)
# drug_train_for_model, zero_lst, r1 = create_update_gene_df(train_df, val_train, list(drug_genes), drug, zero_lst)
# drug_test_for_model, zero_lst, r2 = create_update_gene_df(test_df, val_test, list(drug_genes), drug, zero_lst)
#
# combined_df = pd.concat([drug_train_for_model, drug_test_for_model], ignore_index=True)
#
# y_test, predictions, model = Model_deep(drug_train_for_model, drug_test_for_model,30,10)
# mse, mae, r2 = evaluation(y_test, predictions, drug)
# df_gene = Create_df_one_gene(combined_df)
# if len(drug_r) !=0:
#  pred = model.predict(df_gene)
#
# for col in drug_genes:
#     if (len(drug_r) !=0) and (col in drug_r):
#      gene_antibiotic_df.loc[col, drug] = pred[df_gene.columns.get_loc(col)]
#     else:
#      gene_antibiotic_df.loc[col, drug] = 0.0

# %%
antibiotic_few_samples = []
antibiotic_done = []
for antibiotic in unique_all_antibiotics:
    if len(df[df['drug'] == antibiotic]) < 50:
        antibiotic_few_samples.append(antibiotic)
        continue   
    PredR_Antibiotic(antibiotic)
    antibiotic_done.append(antibiotic)
gene_antibiotic_df.to_csv("Gene_Antibiotic_17/07.csv", index=True, index_label=False)
# Out:
# ************************
#  chloramphenicol
# Epoch 1/40
# 983/983 [==============================] - 3s 2ms/step - loss: 0.1025 - mse: 0.0201
# Epoch 2/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0826 - mse: 0.0137
# Epoch 3/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0823 - mse: 0.0135
# Epoch 4/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0818 - mse: 0.0135
# Epoch 5/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0811 - mse: 0.0134
# Epoch 6/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0813 - mse: 0.0134
# Epoch 7/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0809 - mse: 0.0134
# Epoch 8/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0807 - mse: 0.0133
# Epoch 9/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0805 - mse: 0.0133
# Epoch 10/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0804 - mse: 0.0134
# Epoch 11/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0807 - mse: 0.0134
# Epoch 12/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0807 - mse: 0.0133
# Epoch 13/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0805 - mse: 0.0133
# Epoch 14/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0804 - mse: 0.0133
# Epoch 15/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0799 - mse: 0.0133
# Epoch 16/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0801 - mse: 0.0132
# Epoch 17/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0802 - mse: 0.0133
# Epoch 18/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0801 - mse: 0.0133
# Epoch 19/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0801 - mse: 0.0132
# Epoch 20/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0799 - mse: 0.0133
# Epoch 21/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0798 - mse: 0.0132
# Epoch 22/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0801 - mse: 0.0133
# Epoch 23/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0801 - mse: 0.0133
# Epoch 24/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0796 - mse: 0.0133
# Epoch 25/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0803 - mse: 0.0132
# Epoch 26/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0798 - mse: 0.0132
# Epoch 27/40
# 983/983 [==============================] - 3s 3ms/step - loss: 0.0797 - mse: 0.0132
# Epoch 28/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0800 - mse: 0.0132
# Epoch 29/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0791 - mse: 0.0132
# Epoch 30/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0797 - mse: 0.0132
# Epoch 31/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0802 - mse: 0.0133
# Epoch 32/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0797 - mse: 0.0132
# Epoch 33/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0796 - mse: 0.0132
# Epoch 34/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0796 - mse: 0.0131
# Epoch 35/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0799 - mse: 0.0132
# Epoch 36/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0798 - mse: 0.0132
# Epoch 37/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0799 - mse: 0.0132
# Epoch 38/40
# 983/983 [==============================] - 1s 2ms/step - loss: 0.0796 - mse: 0.0132
# Epoch 39/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0795 - mse: 0.0132
# Epoch 40/40
# 983/983 [==============================] - 2s 2ms/step - loss: 0.0798 - mse: 0.0133
# 78/78 [==============================] - 0s 1ms/step - loss: 0.0822 - mse: 0.0136
# 78/78 [==============================] - 0s 1ms/step
# Loss: 0.08215504884719849
# Mean Squared Error: 0.013582312501966953
# len of pred: (2467, 1) y_test: (2467,)
# Mean Squared Error: 0.013582314756362412
# Mean Absolute Error: 0.03435232680642779
# R^2 Score: 0.7973743101450266
# 1/1 [==============================] - 0s 20ms/step
# ************************
#  clindamycin
# Epoch 1/40
# 292/292 [==============================] - 1s 2ms/step - loss: 0.2643 - mse: 0.0709
# Epoch 2/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1661 - mse: 0.0366
# Epoch 3/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1673 - mse: 0.0369
# Epoch 4/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1656 - mse: 0.0365
# Epoch 5/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1653 - mse: 0.0364
# Epoch 6/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1643 - mse: 0.0363
# Epoch 7/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1655 - mse: 0.0365
# Epoch 8/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1648 - mse: 0.0363
# Epoch 9/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1642 - mse: 0.0364
# Epoch 10/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1644 - mse: 0.0362
# Epoch 11/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1630 - mse: 0.0361
# Epoch 12/40
# 292/292 [==============================] - 1s 2ms/step - loss: 0.1657 - mse: 0.0362
# Epoch 13/40
# 292/292 [==============================] - 1s 2ms/step - loss: 0.1627 - mse: 0.0359
# Epoch 14/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1621 - mse: 0.0358
# Epoch 15/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1647 - mse: 0.0360
# Epoch 16/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1637 - mse: 0.0360
# Epoch 17/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1649 - mse: 0.0359
# Epoch 18/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1639 - mse: 0.0359
# Epoch 19/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1628 - mse: 0.0358
# Epoch 20/40
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1640 - mse: 0.0359
# Epoch 21/40
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1638 - mse: 0.0358
# Epoch 22/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1641 - mse: 0.0359
# Epoch 23/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1629 - mse: 0.0358
# Epoch 24/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1646 - mse: 0.0361
# Epoch 25/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1642 - mse: 0.0359
# Epoch 26/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1640 - mse: 0.0359
# Epoch 27/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1637 - mse: 0.0358
# Epoch 28/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1628 - mse: 0.0356
# Epoch 29/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1642 - mse: 0.0359
# Epoch 30/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1631 - mse: 0.0359
# Epoch 31/40
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1638 - mse: 0.0358
# Epoch 32/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1642 - mse: 0.0358
# Epoch 33/40
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1634 - mse: 0.0358
# Epoch 34/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1631 - mse: 0.0357
# Epoch 35/40
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1630 - mse: 0.0357
# Epoch 36/40
# 292/292 [==============================] - 1s 2ms/step - loss: 0.1635 - mse: 0.0358
# Epoch 37/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1633 - mse: 0.0358
# Epoch 38/40
# 292/292 [==============================] - 0s 1ms/step - loss: 0.1636 - mse: 0.0357
# Epoch 39/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1635 - mse: 0.0357
# Epoch 40/40
# 292/292 [==============================] - 0s 2ms/step - loss: 0.1631 - mse: 0.0357
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1464 - mse: 0.0309
# 24/24 [==============================] - 0s 1ms/step
# Loss: 0.14642676711082458
# Mean Squared Error: 0.030884478241205215
# len of pred: (741, 1) y_test: (741,)
# Mean Squared Error: 0.03088447858842782
# Mean Absolute Error: 0.07038946025068502
# R^2 Score: 0.6569169530167305
# 1/1 [==============================] - 0s 19ms/step
# ************************
#  erythromycin
# Epoch 1/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.3418 - mse: 0.1009
# Epoch 2/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2033 - mse: 0.0473
# Epoch 3/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2033 - mse: 0.0472
# Epoch 4/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2038 - mse: 0.0474
# Epoch 5/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2028 - mse: 0.0473
# Epoch 6/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2021 - mse: 0.0471
# Epoch 7/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2018 - mse: 0.0472
# Epoch 8/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2021 - mse: 0.0471
# Epoch 9/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2021 - mse: 0.0472
# Epoch 10/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2021 - mse: 0.0471
# Epoch 11/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2019 - mse: 0.0471
# Epoch 12/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2016 - mse: 0.0471
# Epoch 13/40
# 306/306 [==============================] - 0s 1ms/step - loss: 0.2027 - mse: 0.0473
# Epoch 14/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2028 - mse: 0.0473
# Epoch 15/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2022 - mse: 0.0471
# Epoch 16/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2021 - mse: 0.0472
# Epoch 17/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2018 - mse: 0.0470
# Epoch 18/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2016 - mse: 0.0472
# Epoch 19/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2012 - mse: 0.0470
# Epoch 20/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2016 - mse: 0.0471
# Epoch 21/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2022 - mse: 0.0471
# Epoch 22/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2017 - mse: 0.0471
# Epoch 23/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2021 - mse: 0.0471
# Epoch 24/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2017 - mse: 0.0471
# Epoch 25/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2035 - mse: 0.0472
# Epoch 26/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2017 - mse: 0.0471
# Epoch 27/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2003 - mse: 0.0469
# Epoch 28/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2017 - mse: 0.0471
# Epoch 29/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2012 - mse: 0.0470
# Epoch 30/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2023 - mse: 0.0472
# Epoch 31/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2017 - mse: 0.0471
# Epoch 32/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2015 - mse: 0.0471
# Epoch 33/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2020 - mse: 0.0471
# Epoch 34/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2016 - mse: 0.0471
# Epoch 35/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2024 - mse: 0.0471
# Epoch 36/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2014 - mse: 0.0471
# Epoch 37/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2016 - mse: 0.0470
# Epoch 38/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2013 - mse: 0.0471
# Epoch 39/40
# 306/306 [==============================] - 0s 2ms/step - loss: 0.2025 - mse: 0.0471
# Epoch 40/40
# 306/306 [==============================] - 1s 2ms/step - loss: 0.2020 - mse: 0.0472
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2060 - mse: 0.0466
# 25/25 [==============================] - 0s 1ms/step
# Loss: 0.2060045599937439
# Mean Squared Error: 0.04656490311026573
# len of pred: (776, 1) y_test: (776,)
# Mean Squared Error: 0.04656490776324781
# Mean Absolute Error: 0.10547156792257663
# R^2 Score: 0.5892603770119638
# 1/1 [==============================] - 0s 19ms/step
# ************************
#  gentamicin
# Epoch 1/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1465 - mse: 0.0312
# Epoch 2/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1207 - mse: 0.0227
# Epoch 3/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1189 - mse: 0.0224
# Epoch 4/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1174 - mse: 0.0219
# Epoch 5/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1170 - mse: 0.0218
# Epoch 6/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1157 - mse: 0.0215
# Epoch 7/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1154 - mse: 0.0215
# Epoch 8/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1145 - mse: 0.0214
# Epoch 9/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1141 - mse: 0.0212
# Epoch 10/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1140 - mse: 0.0212
# Epoch 11/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1138 - mse: 0.0211
# Epoch 12/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1136 - mse: 0.0210
# Epoch 13/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1134 - mse: 0.0211
# Epoch 14/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1128 - mse: 0.0209
# Epoch 15/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1125 - mse: 0.0208
# Epoch 16/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1127 - mse: 0.0208
# Epoch 17/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1120 - mse: 0.0208
# Epoch 18/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1118 - mse: 0.0207
# Epoch 19/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1123 - mse: 0.0208
# Epoch 20/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1121 - mse: 0.0208
# Epoch 21/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1113 - mse: 0.0207
# Epoch 22/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1112 - mse: 0.0206
# Epoch 23/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1116 - mse: 0.0206
# Epoch 24/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1110 - mse: 0.0205
# Epoch 25/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1114 - mse: 0.0206
# Epoch 26/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1108 - mse: 0.0205
# Epoch 27/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1107 - mse: 0.0204
# Epoch 28/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1107 - mse: 0.0205
# Epoch 29/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1104 - mse: 0.0204
# Epoch 30/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1109 - mse: 0.0205
# Epoch 31/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1106 - mse: 0.0204
# Epoch 32/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1104 - mse: 0.0203
# Epoch 33/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1100 - mse: 0.0203
# Epoch 34/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1103 - mse: 0.0204
# Epoch 35/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1103 - mse: 0.0204
# Epoch 36/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1103 - mse: 0.0204
# Epoch 37/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1103 - mse: 0.0204
# Epoch 38/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1103 - mse: 0.0204
# Epoch 39/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1101 - mse: 0.0203
# Epoch 40/40
# 1666/1666 [==============================] - 3s 2ms/step - loss: 0.1099 - mse: 0.0203
# 131/131 [==============================] - 0s 1ms/step - loss: 0.1253 - mse: 0.0206
# 131/131 [==============================] - 0s 1ms/step
# Loss: 0.12527577579021454
# Mean Squared Error: 0.020640553906559944
# len of pred: (4183, 1) y_test: (4183,)
# Mean Squared Error: 0.020640554544391673
# Mean Absolute Error: 0.044745558612275374
# R^2 Score: 0.8390819848182106
# 3/3 [==============================] - 0s 2ms/step
# ************************
#  levofloxacin
# Epoch 1/40
# 430/430 [==============================] - 2s 2ms/step - loss: 0.6810 - mse: 0.2323
# Epoch 2/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6778 - mse: 0.2308
# Epoch 3/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6777 - mse: 0.2307
# Epoch 4/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6776 - mse: 0.2307
# Epoch 5/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6765 - mse: 0.2302
# Epoch 6/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6767 - mse: 0.2303
# Epoch 7/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6766 - mse: 0.2303
# Epoch 8/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6767 - mse: 0.2303
# Epoch 9/40
# 430/430 [==============================] - 1s 1ms/step - loss: 0.6763 - mse: 0.2301
# Epoch 10/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6764 - mse: 0.2302
# Epoch 11/40
# 430/430 [==============================] - 1s 1ms/step - loss: 0.6762 - mse: 0.2301
# Epoch 12/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6761 - mse: 0.2301
# Epoch 13/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6761 - mse: 0.2301
# Epoch 14/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6759 - mse: 0.2300
# Epoch 15/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6756 - mse: 0.2298
# Epoch 16/40
# 430/430 [==============================] - 1s 1ms/step - loss: 0.6762 - mse: 0.2301
# Epoch 17/40
# 430/430 [==============================] - 1s 1ms/step - loss: 0.6759 - mse: 0.2300
# Epoch 18/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6754 - mse: 0.2298
# Epoch 19/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6755 - mse: 0.2298
# Epoch 20/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6755 - mse: 0.2298
# Epoch 21/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6757 - mse: 0.2299
# Epoch 22/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6755 - mse: 0.2299
# Epoch 23/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6754 - mse: 0.2298
# Epoch 24/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6754 - mse: 0.2298
# Epoch 25/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2297
# Epoch 26/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6753 - mse: 0.2298
# Epoch 27/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6758 - mse: 0.2300
# Epoch 28/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2297
# Epoch 29/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6755 - mse: 0.2298
# Epoch 30/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6755 - mse: 0.2299
# Epoch 31/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2297
# Epoch 32/40
# 430/430 [==============================] - 1s 1ms/step - loss: 0.6754 - mse: 0.2298
# Epoch 33/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2297
# Epoch 34/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2297
# Epoch 35/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6753 - mse: 0.2298
# Epoch 36/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2297
# Epoch 37/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6751 - mse: 0.2297
# Epoch 38/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6753 - mse: 0.2298
# Epoch 39/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6750 - mse: 0.2296
# Epoch 40/40
# 430/430 [==============================] - 1s 2ms/step - loss: 0.6752 - mse: 0.2298
# 34/34 [==============================] - 0s 1ms/step - loss: 0.6849 - mse: 0.2319
# 34/34 [==============================] - 0s 1ms/step
# Loss: 0.6849268674850464
# Mean Squared Error: 0.2318616658449173
# len of pred: (1088, 1) y_test: (1088,)
# Mean Squared Error: 0.2318616340939074
# Mean Absolute Error: 0.4644334626387878
# R^2 Score: 0.005698248921177096
# 1/1 [==============================] - 0s 56ms/step
# ************************
#  oxacillin
# Epoch 1/40
# 52/52 [==============================] - 1s 2ms/step - loss: 0.6874 - mse: 0.2471
# Epoch 2/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6764 - mse: 0.2416
# Epoch 3/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6661 - mse: 0.2365
# Epoch 4/40
# 52/52 [==============================] - 0s 1ms/step - loss: 0.6567 - mse: 0.2318
# Epoch 5/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6477 - mse: 0.2273
# Epoch 6/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6395 - mse: 0.2233
# Epoch 7/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6319 - mse: 0.2195
# Epoch 8/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6250 - mse: 0.2162
# Epoch 9/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6185 - mse: 0.2130
# Epoch 10/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6126 - mse: 0.2102
# Epoch 11/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6073 - mse: 0.2076
# Epoch 12/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6022 - mse: 0.2052
# Epoch 13/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5976 - mse: 0.2030
# Epoch 14/40
# 52/52 [==============================] - 0s 1ms/step - loss: 0.5934 - mse: 0.2010
# Epoch 15/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5895 - mse: 0.1992
# Epoch 16/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5860 - mse: 0.1976
# Epoch 17/40
# 52/52 [==============================] - 0s 3ms/step - loss: 0.5828 - mse: 0.1961
# Epoch 18/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5799 - mse: 0.1948
# Epoch 19/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5772 - mse: 0.1936
# Epoch 20/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5748 - mse: 0.1925
# Epoch 21/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5726 - mse: 0.1915
# Epoch 22/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5706 - mse: 0.1906
# Epoch 23/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5688 - mse: 0.1898
# Epoch 24/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5671 - mse: 0.1891
# Epoch 25/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5657 - mse: 0.1885
# Epoch 26/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5644 - mse: 0.1879
# Epoch 27/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5631 - mse: 0.1874
# Epoch 28/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5621 - mse: 0.1869
# Epoch 29/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5612 - mse: 0.1866
# Epoch 30/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5603 - mse: 0.1862
# Epoch 31/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5595 - mse: 0.1859
# Epoch 32/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5588 - mse: 0.1856
# Epoch 33/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5581 - mse: 0.1853
# Epoch 34/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5575 - mse: 0.1851
# Epoch 35/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5570 - mse: 0.1849
# Epoch 36/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5566 - mse: 0.1847
# Epoch 37/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5562 - mse: 0.1845
# Epoch 38/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5558 - mse: 0.1844
# Epoch 39/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5555 - mse: 0.1843
# Epoch 40/40
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5552 - mse: 0.1841
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5542 - mse: 0.1837
# 5/5 [==============================] - 0s 2ms/step
# Loss: 0.5541844964027405
# Mean Squared Error: 0.1836608648300171
# len of pred: (137, 1) y_test: (137,)
# Mean Squared Error: 0.18366085713678898
# Mean Absolute Error: 0.3804239204330166
# R^2 Score: -0.004408691025755251
# ************************
#  penicillin
# Epoch 1/40
# 106/106 [==============================] - 1s 2ms/step - loss: 0.6900 - mse: 0.2088
# Epoch 2/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6845 - mse: 0.2060
# Epoch 3/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6802 - mse: 0.2039
# Epoch 4/40
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6769 - mse: 0.2022
# Epoch 5/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6744 - mse: 0.2010
# Epoch 6/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6725 - mse: 0.2001
# Epoch 7/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6710 - mse: 0.1994
# Epoch 8/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6700 - mse: 0.1988
# Epoch 9/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6693 - mse: 0.1985
# Epoch 10/40
# 106/106 [==============================] - 0s 3ms/step - loss: 0.6688 - mse: 0.1982
# Epoch 11/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6684 - mse: 0.1980
# Epoch 12/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6680 - mse: 0.1979
# Epoch 13/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6679 - mse: 0.1978
# Epoch 14/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6677 - mse: 0.1977
# Epoch 15/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6676 - mse: 0.1977
# Epoch 16/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6676 - mse: 0.1977
# Epoch 17/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6676 - mse: 0.1977
# Epoch 18/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6676 - mse: 0.1977
# Epoch 19/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1977
# Epoch 20/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 21/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 22/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 23/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 24/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 25/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 26/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 27/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 28/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 29/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 30/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 31/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 32/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 33/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 34/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 35/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 36/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6675 - mse: 0.1976
# Epoch 37/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 38/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 39/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# Epoch 40/40
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6674 - mse: 0.1976
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6528 - mse: 0.1994
# 9/9 [==============================] - 0s 1ms/step
# Loss: 0.6528239846229553
# Mean Squared Error: 0.19940349459648132
# len of pred: (269, 1) y_test: (269,)
# Mean Squared Error: 0.19940350608838409
# Mean Absolute Error: 0.41993701945450224
# R^2 Score: -0.005507812129725398
# ************************
#  rifampin
# Epoch 1/40
# 66/66 [==============================] - 1s 2ms/step - loss: 0.6190 - mse: 0.2104
# Epoch 2/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2730 - mse: 0.0671
# Epoch 3/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2580 - mse: 0.0627
# Epoch 4/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2548 - mse: 0.0620
# Epoch 5/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2567 - mse: 0.0622
# Epoch 6/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2548 - mse: 0.0618
# Epoch 7/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2549 - mse: 0.0618
# Epoch 8/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2550 - mse: 0.0617
# Epoch 9/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2539 - mse: 0.0614
# Epoch 10/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2557 - mse: 0.0616
# Epoch 11/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2531 - mse: 0.0611
# Epoch 12/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2525 - mse: 0.0611
# Epoch 13/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2528 - mse: 0.0611
# Epoch 14/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2527 - mse: 0.0611
# Epoch 15/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2524 - mse: 0.0611
# Epoch 16/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2530 - mse: 0.0612
# Epoch 17/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2531 - mse: 0.0612
# Epoch 18/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2530 - mse: 0.0612
# Epoch 19/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2534 - mse: 0.0612
# Epoch 20/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2532 - mse: 0.0611
# Epoch 21/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2534 - mse: 0.0612
# Epoch 22/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2532 - mse: 0.0612
# Epoch 23/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2529 - mse: 0.0612
# Epoch 24/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2533 - mse: 0.0612
# Epoch 25/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2541 - mse: 0.0613
# Epoch 26/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2519 - mse: 0.0610
# Epoch 27/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2528 - mse: 0.0611
# Epoch 28/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2576 - mse: 0.0619
# Epoch 29/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2564 - mse: 0.0615
# Epoch 30/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2522 - mse: 0.0611
# Epoch 31/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2544 - mse: 0.0614
# Epoch 32/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2523 - mse: 0.0611
# Epoch 33/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2517 - mse: 0.0610
# Epoch 34/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2526 - mse: 0.0611
# Epoch 35/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2533 - mse: 0.0612
# Epoch 36/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2534 - mse: 0.0612
# Epoch 37/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2519 - mse: 0.0611
# Epoch 38/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2540 - mse: 0.0613
# Epoch 39/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2528 - mse: 0.0612
# Epoch 40/40
# 66/66 [==============================] - 0s 2ms/step - loss: 0.2530 - mse: 0.0612
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2533 - mse: 0.0621
# 6/6 [==============================] - 0s 1ms/step
# Loss: 0.2533121407032013
# Mean Squared Error: 0.06206677854061127
# len of pred: (172, 1) y_test: (172,)
# Mean Squared Error: 0.06206677979579594
# Mean Absolute Error: 0.11923113429606189
# R^2 Score: 0.07310266861240422
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  tetracycline
# Epoch 1/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1633 - mse: 0.0362
# Epoch 2/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1372 - mse: 0.0269
# Epoch 3/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1354 - mse: 0.0267
# Epoch 4/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1357 - mse: 0.0266
# Epoch 5/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1352 - mse: 0.0266
# Epoch 6/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1345 - mse: 0.0264
# Epoch 7/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1349 - mse: 0.0264
# Epoch 8/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1341 - mse: 0.0264
# Epoch 9/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1346 - mse: 0.0263
# Epoch 10/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1341 - mse: 0.0263
# Epoch 11/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1341 - mse: 0.0263
# Epoch 12/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1343 - mse: 0.0263
# Epoch 13/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1341 - mse: 0.0263
# Epoch 14/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1340 - mse: 0.0263
# Epoch 15/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1340 - mse: 0.0263
# Epoch 16/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 17/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1338 - mse: 0.0262
# Epoch 18/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1338 - mse: 0.0262
# Epoch 19/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 20/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1338 - mse: 0.0262
# Epoch 21/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1339 - mse: 0.0262
# Epoch 22/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1341 - mse: 0.0262
# Epoch 23/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1338 - mse: 0.0263
# Epoch 24/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 25/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1338 - mse: 0.0263
# Epoch 26/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 27/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1334 - mse: 0.0262
# Epoch 28/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 29/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1338 - mse: 0.0262
# Epoch 30/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1332 - mse: 0.0262
# Epoch 31/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1331 - mse: 0.0262
# Epoch 32/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 33/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 34/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1334 - mse: 0.0262
# Epoch 35/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1332 - mse: 0.0262
# Epoch 36/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1330 - mse: 0.0261
# Epoch 37/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1332 - mse: 0.0261
# Epoch 38/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1333 - mse: 0.0261
# Epoch 39/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 40/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1332 - mse: 0.0262
# 128/128 [==============================] - 0s 1ms/step - loss: 0.1453 - mse: 0.0294
# 128/128 [==============================] - 0s 1ms/step
# Loss: 0.14526931941509247
# Mean Squared Error: 0.029367011040449142
# len of pred: (4091, 1) y_test: (4091,)
# Mean Squared Error: 0.02936701339513521
# Mean Absolute Error: 0.06329432715926127
# R^2 Score: 0.879808868733028
# 2/2 [==============================] - 0s 3ms/step
# ************************
#  trimethoprim-sulfamethoxazole
# Epoch 1/40
# 1324/1324 [==============================] - 3s 2ms/step - loss: 0.2835 - mse: 0.0883
# Epoch 2/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2669 - mse: 0.0827
# Epoch 3/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2657 - mse: 0.0823
# Epoch 4/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2656 - mse: 0.0821
# Epoch 5/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2652 - mse: 0.0821
# Epoch 6/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2650 - mse: 0.0820
# Epoch 7/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2648 - mse: 0.0818
# Epoch 8/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2644 - mse: 0.0819
# Epoch 9/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2652 - mse: 0.0820
# Epoch 10/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2644 - mse: 0.0818
# Epoch 11/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2648 - mse: 0.0819
# Epoch 12/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2646 - mse: 0.0819
# Epoch 13/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2644 - mse: 0.0817
# Epoch 14/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2640 - mse: 0.0817
# Epoch 15/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2640 - mse: 0.0817
# Epoch 16/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2646 - mse: 0.0818
# Epoch 17/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2646 - mse: 0.0818
# Epoch 18/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2641 - mse: 0.0817
# Epoch 19/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2643 - mse: 0.0818
# Epoch 20/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2645 - mse: 0.0817
# Epoch 21/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2638 - mse: 0.0817
# Epoch 22/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2641 - mse: 0.0817
# Epoch 23/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2640 - mse: 0.0817
# Epoch 24/40
# 1324/1324 [==============================] - 3s 2ms/step - loss: 0.2642 - mse: 0.0817
# Epoch 25/40
# 1324/1324 [==============================] - 3s 2ms/step - loss: 0.2640 - mse: 0.0817
# Epoch 26/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2643 - mse: 0.0817
# Epoch 27/40
# 1324/1324 [==============================] - 3s 2ms/step - loss: 0.2638 - mse: 0.0816
# Epoch 28/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 29/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2638 - mse: 0.0816
# Epoch 30/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2641 - mse: 0.0817
# Epoch 31/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2636 - mse: 0.0816
# Epoch 32/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0816
# Epoch 33/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 34/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2637 - mse: 0.0816
# Epoch 35/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 36/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0816
# Epoch 37/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2640 - mse: 0.0817
# Epoch 38/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0816
# Epoch 39/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2637 - mse: 0.0816
# Epoch 40/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2637 - mse: 0.0816
# 104/104 [==============================] - 0s 1ms/step - loss: 0.2644 - mse: 0.0829
# 104/104 [==============================] - 0s 2ms/step
# Loss: 0.26443561911582947
# Mean Squared Error: 0.08285827189683914
# len of pred: (3323, 1) y_test: (3323,)
# Mean Squared Error: 0.08285828777597937
# Mean Absolute Error: 0.1651106080880572
# R^2 Score: 0.3635681187411972
# 1/1 [==============================] - 0s 30ms/step
# ************************
#  vancomycin
# Epoch 1/40
# 68/68 [==============================] - 1s 2ms/step - loss: 0.6450 - mse: 0.2239
# Epoch 2/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3016 - mse: 0.0796
# Epoch 3/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2257 - mse: 0.0546
# Epoch 4/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2169 - mse: 0.0517
# Epoch 5/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2159 - mse: 0.0505
# Epoch 6/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2144 - mse: 0.0502
# Epoch 7/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2139 - mse: 0.0500
# Epoch 8/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2125 - mse: 0.0496
# Epoch 9/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2131 - mse: 0.0496
# Epoch 10/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2131 - mse: 0.0496
# Epoch 11/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2130 - mse: 0.0496
# Epoch 12/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2118 - mse: 0.0494
# Epoch 13/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2132 - mse: 0.0497
# Epoch 14/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2131 - mse: 0.0496
# Epoch 15/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2129 - mse: 0.0495
# Epoch 16/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2118 - mse: 0.0495
# Epoch 17/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2119 - mse: 0.0495
# Epoch 18/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2118 - mse: 0.0495
# Epoch 19/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2128 - mse: 0.0498
# Epoch 20/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2118 - mse: 0.0495
# Epoch 21/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2127 - mse: 0.0497
# Epoch 22/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2116 - mse: 0.0495
# Epoch 23/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2122 - mse: 0.0495
# Epoch 24/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2121 - mse: 0.0495
# Epoch 25/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2125 - mse: 0.0496
# Epoch 26/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2139 - mse: 0.0497
# Epoch 27/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2125 - mse: 0.0495
# Epoch 28/40
# 68/68 [==============================] - 0s 3ms/step - loss: 0.2123 - mse: 0.0495
# Epoch 29/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2119 - mse: 0.0495
# Epoch 30/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2110 - mse: 0.0495
# Epoch 31/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2119 - mse: 0.0495
# Epoch 32/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2115 - mse: 0.0494
# Epoch 33/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2113 - mse: 0.0495
# Epoch 34/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2118 - mse: 0.0495
# Epoch 35/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2115 - mse: 0.0495
# Epoch 36/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2134 - mse: 0.0497
# Epoch 37/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2123 - mse: 0.0495
# Epoch 38/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2112 - mse: 0.0494
# Epoch 39/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2121 - mse: 0.0495
# Epoch 40/40
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2121 - mse: 0.0496
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2312 - mse: 0.0572
# 6/6 [==============================] - 0s 2ms/step
# Loss: 0.23119224607944489
# Mean Squared Error: 0.05718425288796425
# len of pred: (180, 1) y_test: (180,)
# Mean Squared Error: 0.05718425527163459
# Mean Absolute Error: 0.10791705125140855
# R^2 Score: 0.15888327281763237
# 1/1 [==============================] - 0s 20ms/step
# ************************
#  ampicillin
# Epoch 1/40
# 1309/1309 [==============================] - 3s 2ms/step - loss: 0.6782 - mse: 0.2411
# Epoch 2/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6725 - mse: 0.2383
# Epoch 3/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2382
# Epoch 4/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 5/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 6/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 7/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 8/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 9/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 10/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# Epoch 11/40
# 1309/1309 [==============================] - 2s 2ms/step - loss: 0.6724 - mse: 0.2383
# ...
# Mean Squared Error: 0.09429704190648473
# Mean Absolute Error: 0.1798594177708795
# R^2 Score: 0.013649724536163088
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  streptomycin
# Epoch 1/40
# 924/924 [==============================] - 2s 1ms/step - loss: 0.2606 - mse: 0.0712
# Epoch 2/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2283 - mse: 0.0583
# Epoch 3/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2247 - mse: 0.0575
# Epoch 4/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2240 - mse: 0.0573
# Epoch 5/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2246 - mse: 0.0575
# Epoch 6/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2238 - mse: 0.0572
# Epoch 7/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2233 - mse: 0.0571
# Epoch 8/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2234 - mse: 0.0569
# Epoch 9/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2232 - mse: 0.0569
# Epoch 10/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2232 - mse: 0.0569
# Epoch 11/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2226 - mse: 0.0569
# Epoch 12/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2220 - mse: 0.0567
# Epoch 13/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2231 - mse: 0.0570
# Epoch 14/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2223 - mse: 0.0568
# Epoch 15/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2223 - mse: 0.0568
# Epoch 16/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2227 - mse: 0.0568
# Epoch 17/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2216 - mse: 0.0566
# Epoch 18/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2215 - mse: 0.0567
# Epoch 19/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2210 - mse: 0.0565
# Epoch 20/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2210 - mse: 0.0565
# Epoch 21/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2208 - mse: 0.0564
# Epoch 22/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2216 - mse: 0.0566
# Epoch 23/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2213 - mse: 0.0565
# Epoch 24/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2207 - mse: 0.0565
# Epoch 25/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2207 - mse: 0.0565
# Epoch 26/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2208 - mse: 0.0564
# Epoch 27/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2213 - mse: 0.0566
# Epoch 28/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2205 - mse: 0.0563
# Epoch 29/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2206 - mse: 0.0564
# Epoch 30/40
# 924/924 [==============================] - 2s 2ms/step - loss: 0.2213 - mse: 0.0566
# Epoch 31/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2204 - mse: 0.0563
# Epoch 32/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2207 - mse: 0.0564
# Epoch 33/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2206 - mse: 0.0564
# Epoch 34/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2204 - mse: 0.0563
# Epoch 35/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2205 - mse: 0.0564
# Epoch 36/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2206 - mse: 0.0564
# Epoch 37/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2202 - mse: 0.0563
# Epoch 38/40
# 924/924 [==============================] - 1s 1ms/step - loss: 0.2202 - mse: 0.0563
# Epoch 39/40
# 924/924 [==============================] - 1s 2ms/step - loss: 0.2205 - mse: 0.0563
# Epoch 40/40
# 924/924 [==============================] - 2s 2ms/step - loss: 0.2199 - mse: 0.0562
# 73/73 [==============================] - 0s 1ms/step - loss: 0.2047 - mse: 0.0505
# 73/73 [==============================] - 0s 1ms/step
# Loss: 0.20466649532318115
# Mean Squared Error: 0.05049477890133858
# len of pred: (2317, 1) y_test: (2317,)
# Mean Squared Error: 0.050494783398724
# Mean Absolute Error: 0.09978932489378728
# R^2 Score: 0.7818659959633625
# 2/2 [==============================] - 0s 3ms/step
# ************************
#  sulfamethoxazole
# Epoch 1/40
# 63/63 [==============================] - 1s 2ms/step - loss: 0.5006 - mse: 0.1703
# Epoch 2/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4019 - mse: 0.1323
# Epoch 3/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1568 - mse: 0.0326
# Epoch 4/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0746 - mse: 0.0124
# Epoch 5/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0778 - mse: 0.0124
# Epoch 6/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0758 - mse: 0.0123
# Epoch 7/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0756 - mse: 0.0123
# Epoch 8/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0760 - mse: 0.0123
# Epoch 9/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0740 - mse: 0.0123
# Epoch 10/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0742 - mse: 0.0124
# Epoch 11/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0766 - mse: 0.0123
# Epoch 12/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0736 - mse: 0.0123
# Epoch 13/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0749 - mse: 0.0123
# Epoch 14/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0736 - mse: 0.0122
# Epoch 15/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0739 - mse: 0.0123
# Epoch 16/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0746 - mse: 0.0123
# Epoch 17/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0724 - mse: 0.0124
# Epoch 18/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0757 - mse: 0.0123
# Epoch 19/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0733 - mse: 0.0122
# Epoch 20/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0739 - mse: 0.0123
# Epoch 21/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0727 - mse: 0.0123
# Epoch 22/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0741 - mse: 0.0123
# Epoch 23/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0754 - mse: 0.0123
# Epoch 24/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0726 - mse: 0.0123
# Epoch 25/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0735 - mse: 0.0122
# Epoch 26/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0736 - mse: 0.0123
# Epoch 27/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0769 - mse: 0.0124
# Epoch 28/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0740 - mse: 0.0124
# Epoch 29/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0747 - mse: 0.0123
# Epoch 30/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0741 - mse: 0.0122
# Epoch 31/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0729 - mse: 0.0123
# Epoch 32/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0745 - mse: 0.0123
# Epoch 33/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0753 - mse: 0.0123
# Epoch 34/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0744 - mse: 0.0123
# Epoch 35/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0717 - mse: 0.0122
# Epoch 36/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0732 - mse: 0.0122
# Epoch 37/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0727 - mse: 0.0122
# Epoch 38/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0729 - mse: 0.0122
# Epoch 39/40
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0739 - mse: 0.0122
# Epoch 40/40
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0727 - mse: 0.0123
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0685 - mse: 0.0092
# 6/6 [==============================] - 0s 2ms/step
# Loss: 0.06848520040512085
# Mean Squared Error: 0.009165002964437008
# len of pred: (162, 1) y_test: (162,)
# Mean Squared Error: 0.009165002296572907
# Mean Absolute Error: 0.02569421761335782
# R^2 Score: 0.9620381438965815
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  tetracycline
# Epoch 1/40
# 1630/1630 [==============================] - 3s 1ms/step - loss: 0.1896 - mse: 0.0462
# Epoch 2/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1373 - mse: 0.0269
# Epoch 3/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1363 - mse: 0.0267
# Epoch 4/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1356 - mse: 0.0265
# Epoch 5/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1352 - mse: 0.0265
# Epoch 6/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1347 - mse: 0.0264
# Epoch 7/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1349 - mse: 0.0264
# Epoch 8/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1349 - mse: 0.0264
# Epoch 9/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1341 - mse: 0.0263
# Epoch 10/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1346 - mse: 0.0264
# Epoch 11/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1344 - mse: 0.0263
# Epoch 12/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1346 - mse: 0.0263
# Epoch 13/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1342 - mse: 0.0263
# Epoch 14/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1344 - mse: 0.0262
# Epoch 15/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1339 - mse: 0.0263
# Epoch 16/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 17/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1341 - mse: 0.0262
# Epoch 18/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1334 - mse: 0.0261
# Epoch 19/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1340 - mse: 0.0262
# Epoch 20/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 21/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1334 - mse: 0.0261
# Epoch 22/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1337 - mse: 0.0262
# Epoch 23/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 24/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 25/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1337 - mse: 0.0262
# Epoch 26/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1337 - mse: 0.0262
# Epoch 27/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1333 - mse: 0.0262
# Epoch 28/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1334 - mse: 0.0262
# Epoch 29/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1333 - mse: 0.0262
# Epoch 30/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1336 - mse: 0.0262
# Epoch 31/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1334 - mse: 0.0261
# Epoch 32/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1332 - mse: 0.0261
# Epoch 33/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1333 - mse: 0.0262
# Epoch 34/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 35/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1333 - mse: 0.0261
# Epoch 36/40
# 1630/1630 [==============================] - 3s 2ms/step - loss: 0.1331 - mse: 0.0261
# Epoch 37/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1335 - mse: 0.0262
# Epoch 38/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1332 - mse: 0.0261
# Epoch 39/40
# 1630/1630 [==============================] - 2s 1ms/step - loss: 0.1333 - mse: 0.0261
# Epoch 40/40
# 1630/1630 [==============================] - 2s 2ms/step - loss: 0.1332 - mse: 0.0261
# 128/128 [==============================] - 0s 1ms/step - loss: 0.1471 - mse: 0.0296
# 128/128 [==============================] - 0s 922us/step
# Loss: 0.14714130759239197
# Mean Squared Error: 0.02959548495709896
# len of pred: (4091, 1) y_test: (4091,)
# Mean Squared Error: 0.029595481743704105
# Mean Absolute Error: 0.05719434200717531
# R^2 Score: 0.8788738104448828
# 2/2 [==============================] - 0s 3ms/step
# ************************
#  trimethoprim-sulfamethoxazole
# Epoch 1/40
# 1324/1324 [==============================] - 3s 1ms/step - loss: 0.2818 - mse: 0.0879
# Epoch 2/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2667 - mse: 0.0827
# Epoch 3/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2662 - mse: 0.0826
# Epoch 4/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2655 - mse: 0.0823
# Epoch 5/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2655 - mse: 0.0822
# Epoch 6/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2655 - mse: 0.0822
# Epoch 7/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2645 - mse: 0.0818
# Epoch 8/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2649 - mse: 0.0819
# Epoch 9/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2647 - mse: 0.0819
# Epoch 10/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2645 - mse: 0.0818
# Epoch 11/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2643 - mse: 0.0818
# Epoch 12/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2649 - mse: 0.0819
# Epoch 13/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2645 - mse: 0.0819
# Epoch 14/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2640 - mse: 0.0819
# Epoch 15/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2641 - mse: 0.0818
# Epoch 16/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2645 - mse: 0.0818
# Epoch 17/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2643 - mse: 0.0817
# Epoch 18/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2644 - mse: 0.0818
# Epoch 19/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 20/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2645 - mse: 0.0818
# Epoch 21/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 22/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2643 - mse: 0.0817
# Epoch 23/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 24/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2642 - mse: 0.0817
# Epoch 25/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2637 - mse: 0.0817
# Epoch 26/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2635 - mse: 0.0816
# Epoch 27/40
# 1324/1324 [==============================] - 2s 2ms/step - loss: 0.2640 - mse: 0.0817
# Epoch 28/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2639 - mse: 0.0817
# Epoch 29/40
# 1324/1324 [==============================] - 2s 1ms/step - loss: 0.2639 - mse: 0.0816
# Epoch 30/40
#  612/1324 [============>.................] - ETA: 1s - loss: 0.2612 - mse: 0.0817
