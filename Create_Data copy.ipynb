# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def clean_gene(df, column):
    # Copy the dataframe to avoid modifying the original
    df = df.copy()

    # Replace hyphen '-' and '(' ')' with nothing
    df[column] = df[column].str.replace(r'[-\(\)\'\?\_]', '', regex=True)

    # Convert all upper case to lower case
    df[column] = df[column].str.lower()

    return df

# %%
val_data = pd.read_csv("refgenes.csv")
val_data.head(10)
# Out:
#   Gene family Scope Type           Class                           Subclass
# 0         16S  core  AMR    TETRACYCLINE                       TETRACYCLINE
# 1         16S  core  AMR  AMINOGLYCOSIDE  GENTAMICIN C/NEOMYCIN/PAROMOMYCIN
# 2         16S  core  AMR          EDEINE                             EDEINE
# 3         16S  core  AMR  AMINOGLYCOSIDE                        KASUGAMYCIN
# 4         16S  core  AMR  AMINOGLYCOSIDE                        KASUGAMYCIN
# 5         16S  core  AMR  AMINOGLYCOSIDE                        KASUGAMYCIN
# 6         16S  core  AMR  AMINOGLYCOSIDE                       STREPTOMYCIN
# 7         16S  core  AMR  AMINOGLYCOSIDE                        KASUGAMYCIN
# 8         16S  core  AMR  AMINOGLYCOSIDE                        KASUGAMYCIN
# 9         16S  core  AMR    TETRACYCLINE                       TETRACYCLINE

# %%
val_data.drop('Class', axis=1, inplace=True)
val_data.drop('Scope', axis=1, inplace=True)
val_data.drop('Type', axis=1, inplace=True)
val_data.drop_duplicates(inplace=True)
val_data['Subclass'] = val_data['Subclass'].str.lower()
val_data['Subclass'] = val_data['Subclass'].str.split('/')
val_data = val_data.explode('Subclass')
val_data['Gene family'] = val_data['Gene family'].str.split('/')
val_data = val_data.explode('Gene family')
val_data.drop_duplicates(inplace=True)
val_data.dropna(inplace=True)
val_data.reset_index(drop=True, inplace=True)
val_data = clean_gene(val_data,'Gene family')
val_data.drop_duplicates(inplace=True)
val_data
# Out:
#      Gene family                       Subclass
# 0            16s                   tetracycline
# 1            16s                   gentamicin c
# 2            16s                       neomycin
# 3            16s                    paromomycin
# 4            16s                         edeine
# ...          ...                            ...
# 1397        uhpa                     fosfomycin
# 1398        uhpt                     fosfomycin
# 1399        walk                     daptomycin
# 1400        yciv  trimethoprim-sulfamethoxazole
# 1401        yybt                     daptomycin
#
# [1391 rows x 2 columns]

# %%
val_data.to_csv("val_data.csv", index=False)

# %%
data = pd.read_csv(r'isolates.csv')
data.head(10)
# Out:
#           #Organism group         Isolate  \
# 0  Listeria monocytogenes  PDT000077416.3
# 1  Listeria monocytogenes  PDT000095192.3
# 2     Salmonella enterica  PDT000003687.3
# 3     Salmonella enterica  PDT000003688.4
# 4     Salmonella enterica  PDT000003689.4
# 5     Salmonella enterica  PDT000003690.3
# 6     Salmonella enterica  PDT000003691.3
# 7     Salmonella enterica  PDT000003692.3
# 8     Salmonella enterica  PDT000003693.3
# 9     Salmonella enterica  PDT000003694.4
#
#                                        AMR genotypes  \
# 0                         fosX=COMPLETE,lin=COMPLETE
# 1                         fosX=COMPLETE,lin=COMPLETE
# 2                        mdsA=COMPLETE,mdsB=COMPLETE
# 3                        mdsA=COMPLETE,mdsB=COMPLETE
# 4                        mdsA=COMPLETE,mdsB=COMPLETE
# 5  aph(3'')-Ib=COMPLETE,aph(6)-Id=COMPLETE,mdsA=C...
# 6        mdsA=COMPLETE,mdsB=COMPLETE,tet(B)=COMPLETE
# 7                        mdsA=COMPLETE,mdsB=COMPLETE
# 8  aph(3'')-Ib=COMPLETE,aph(6)-Id=COMPLETE,mdsA=C...
# 9         fosA7=COMPLETE,mdsA=COMPLETE,mdsB=COMPLETE
#
#                                       AST phenotypes
# 0  chloramphenicol=S,clindamycin=R,erythromycin=S...
# 1                          ampicillin=S,penicillin=S
# 2  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 3  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 4  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 5  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 6  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 7  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 8  amikacin=S,amoxicillin-clavulanic acid=S,ampic...
# 9  amikacin=S,amoxicillin-clavulanic acid=S,ampic...

# %%
anti_family = pd.read_csv("anti_family.csv")
anti_family.head(10)
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   gene family         gene                     antibiotic         drug_class  \
# 0    ANT(2'')  ANT(2'')-Ia                  spectinomycin     aminoglycoside
# 1    ANT(2'')  ANT(2'')-Ia  trimethoprim-sulfamethoxazole  diaminopyrimidine
# 2    ANT(2'')  ANT(2'')-Ia                   azithromycin          macrolide
# 3    ANT(2'')  ANT(2'')-Ia          ceftazidime-avibactam     beta-lactamase
# 4    ANT(2'')  ANT(2'')-Ia                   piperacillin         Penicillin
# 5    ANT(2'')  ANT(2'')-Ia                    ticarcillin         Penicillin
# 6    ANT(2'')  ANT(2'')-Ia                      kanamycin     Aminoglycoside
# 7    ANT(2'')  ANT(2'')-Ia                      oxacillin         Penicillin
# 8    ANT(2'')  ANT(2'')-Ia                      tedizolid      Oxazolidinone
# 9    ANT(2'')  ANT(2'')-Ia                    cefiderocol     beta-lactamase
#
#      S    R
# 0  NaN  1.0
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN
# 5  NaN  NaN
# 6  NaN  1.0
# 7  NaN  NaN
# 8  NaN  NaN
# 9  NaN  NaN

# %%
# gene_anti_R = pd.read_csv("gene_anti_R.csv")
# gene_anti_R.head(10)

# %%
# anti_family.loc[anti_family['antibiotic'].str.contains('trimethoprim'), 'R'] = None
# merged_df = anti_family.merge(gene_anti_R, left_on='gene', right_on='aro_term', how='left')
# merged_df.drop_duplicates(inplace=True)
# merged_df.to_csv('merged_df.csv', index=False)
# # Check if there is any row where both 'drug_class_x' and 'drug_class_y' contain 'diaminopyrimidine'
# diaminopyrimidine_rows = (merged_df['drug_class_x'].str.contains('diaminopyrimidine') & merged_df['drug_class_y'].str.contains('diaminopyrimidine'))
#
# # Filter 'anti_family' to get rows matching the condition
# matched_rows = anti_family[anti_family['gene'].isin(merged_df.loc[diaminopyrimidine_rows, 'gene'])]
#
# # Update the 'R' and 'S' columns for matched rows in 'anti_family'
# anti_family.loc[matched_rows.index, 'R'] = 1
# anti_family.loc[matched_rows.index, 'S'] = None
# anti_family.to_csv("anti_family.csv",index=False)

# %%
# gene_anti_R.drop('prevalence_sequence_id', axis=1, inplace=True)
# gene_anti_R.drop('model_id', axis=1, inplace=True)
# gene_anti_R.drop('aro_accession', axis=1, inplace=True)
# gene_anti_R.drop('detection_model', axis=1, inplace=True)
# gene_anti_R.drop('species_name', axis=1, inplace=True)
# gene_anti_R.drop('ncbi_accession', axis=1, inplace=True)
# gene_anti_R.drop('data_type', axis=1, inplace=True)
# gene_anti_R.drop('rgi_criteria', axis=1, inplace=True)
# gene_anti_R.drop('percent_identity', axis=1, inplace=True)
# gene_anti_R.drop('bitscore', axis=1, inplace=True)
# gene_anti_R.drop('amr_gene_family', axis=1, inplace=True)
# gene_anti_R.drop('resistance_mechanism', axis=1, inplace=True)
# val_data.drop_duplicates(inplace=True)
# gene_anti_R.to_csv("gene_anti_R.csv", index=False)

# %%
anti_family = clean_gene(anti_family,'gene')
anti_family
# Out:
#        gene family    gene                     antibiotic         drug_class  \
# 0         ANT(2'')  ant2ia                  spectinomycin     aminoglycoside
# 1         ANT(2'')  ant2ia  trimethoprim-sulfamethoxazole  diaminopyrimidine
# 2         ANT(2'')  ant2ia                   azithromycin          macrolide
# 3         ANT(2'')  ant2ia          ceftazidime-avibactam     beta-lactamase
# 4         ANT(2'')  ant2ia                   piperacillin         Penicillin
# ...            ...     ...                            ...                ...
# 264379         NaN  mcr2.3                    ceftazidime     beta-lactamase
# 264380         NaN  mcr2.3    amoxicillin-clavulanic acid     beta-lactamase
# 264381         NaN  mcr2.3                   streptomycin     Aminoglycoside
# 264382         NaN  mcr2.3                   moxifloxacin          Quinolone
# 264383         NaN  mcr2.3                  metronidazole         nitrofuran
#
#           S    R
# 0       NaN  1.0
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# 4       NaN  NaN
# ...     ...  ...
# 264379  NaN  NaN
# 264380  NaN  NaN
# 264381  NaN  NaN
# 264382  NaN  NaN
# 264383  NaN  NaN
#
# [264384 rows x 6 columns]

# %%
def transform_dataframe(df):
    new_data = []

    for idx, row in df.iterrows():
        # split AMR genotypes and remove "=COMPLETE"
        amr_genotypes = [pheno.split('=')[0] for pheno in row['AMR genotypes'].split(',') if '=POINT' not in pheno]

        # split AST phenotypes and remove "=POINT"
        ast_phenotypes = row['AST phenotypes'].split(',')

        # process each phenotype
        for pheno in ast_phenotypes:
            drug, resistance = pheno.split('=')
            if resistance == 'R':
                resistance_score = 1
            elif resistance == 'S':
                resistance_score = 0
            else:  # assuming 'I' as per your description
                resistance_score = 0.5

            # create a new row
            new_row = {'#Organism group': row['#Organism group'],
                       'Isolate': row['Isolate'],
                       'AMR genotypes': ', '.join(amr_genotypes),
                       'drug': drug,
                       'resistance': resistance_score}
            new_data.append(new_row)

    # create a new dataframe
    new_df = pd.DataFrame(new_data)

    return new_df

# %%
df = transform_dataframe(data)

# %%
df.to_csv("BasicData.csv",index=False)
df.head(10)
# Out:
#           #Organism group         Isolate AMR genotypes  \
# 0  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 1  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 2  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 3  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 4  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 5  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 6  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 7  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 8  Listeria monocytogenes  PDT000077416.3     fosX, lin
# 9  Listeria monocytogenes  PDT000077416.3     fosX, lin
#
#                             drug  resistance
# 0                chloramphenicol         0.0
# 1                    clindamycin         1.0
# 2                   erythromycin         0.0
# 3                     gentamicin         0.0
# 4                   levofloxacin         0.0
# 5                      oxacillin         1.0
# 6                     penicillin         0.0
# 7                       rifampin         0.0
# 8                   tetracycline         0.0
# 9  trimethoprim-sulfamethoxazole         0.0

# %%
df = clean_gene(df, 'AMR genotypes')
df
# Out:
#                   #Organism group         Isolate  \
# 0          Listeria monocytogenes  PDT000077416.3
# 1          Listeria monocytogenes  PDT000077416.3
# 2          Listeria monocytogenes  PDT000077416.3
# 3          Listeria monocytogenes  PDT000077416.3
# 4          Listeria monocytogenes  PDT000077416.3
# ...                           ...             ...
# 316066  Enterobacter roggenkampii  PDT000898827.2
# 316067  Enterobacter roggenkampii  PDT000898827.2
# 316068  Enterobacter roggenkampii  PDT001161812.2
# 316069  Enterobacter roggenkampii  PDT001161812.2
# 316070  Enterobacter roggenkampii  PDT001161812.2
#
#                                   AMR genotypes  \
# 0                                     fosx, lin
# 1                                     fosx, lin
# 2                                     fosx, lin
# 3                                     fosx, lin
# 4                                     fosx, lin
# ...                                         ...
# 316066  blamir, cata, fosa, mcr10.1, oqxa, oqxb
# 316067  blamir, cata, fosa, mcr10.1, oqxa, oqxb
# 316068               blamir16, cata, fosa, oqxb
# 316069               blamir16, cata, fosa, oqxb
# 316070               blamir16, cata, fosa, oqxb
#
#                                  drug  resistance
# 0                     chloramphenicol         0.0
# 1                         clindamycin         1.0
# 2                        erythromycin         0.0
# 3                          gentamicin         0.0
# 4                        levofloxacin         0.0
# ...                               ...         ...
# 316066                   tetracycline         0.0
# 316067  trimethoprim-sulfamethoxazole         0.0
# 316068                      ertapenem         0.0
# 316069                       imipenem         0.5
# 316070                      meropenem         0.0
#
# [316071 rows x 5 columns]

# %%
print((df['resistance'] == 0.5).sum())
# Out:
# 10661

# %%
df.to_csv("BasicData_clean.csv",index=False)

# %%
def create_empty_gene_antibiotic_df(df):
    unique_all_genes = []
    unique_all_antibiotics = []

    for idx, row in df.iterrows():
        genotypes = row['AMR genotypes'].split(', ')
        antibiotic = row['drug']

        unique_all_genes.extend(genotypes)
        unique_all_antibiotics.append(antibiotic)

    unique_all_genes = list(set(unique_all_genes))  # Convert to list
    unique_all_antibiotics = list(set(unique_all_antibiotics))  # Convert to list

    gene_antibiotic_df = pd.DataFrame(index=unique_all_genes, columns=unique_all_antibiotics)
    gene_antibiotic_df = gene_antibiotic_df.fillna(-1)

    return gene_antibiotic_df, unique_all_antibiotics, unique_all_genes

# Assuming your DataFrame is named 'new_dataframe'
gene_antibiotic_df, unique_all_antibiotics, unique_all_genes = create_empty_gene_antibiotic_df(df)
gene_antibiotic_df
# Out:
#            ceftiofur  cefalexin  doxycycline  neomycin  ticarcillin  rifampin  \
# blapdc19b         -1         -1           -1        -1           -1        -1
# ant6ia            -1         -1           -1        -1           -1        -1
# blaoxa120         -1         -1           -1        -1           -1        -1
# mefc              -1         -1           -1        -1           -1        -1
# blaec             -1         -1           -1        -1           -1        -1
# ...              ...        ...          ...       ...          ...       ...
# blapme1           -1         -1           -1        -1           -1        -1
# blalen9           -1         -1           -1        -1           -1        -1
# blapdc103         -1         -1           -1        -1           -1        -1
# blaact66          -1         -1           -1        -1           -1        -1
# blaact55          -1         -1           -1        -1           -1        -1
#
#            zoliflodacin  fosfomycin-glucose-6-phosphate  ampicillin-sulbactam  \
# blapdc19b            -1                              -1                    -1
# ant6ia               -1                              -1                    -1
# blaoxa120            -1                              -1                    -1
# mefc                 -1                              -1                    -1
# blaec                -1                              -1                    -1
# ...                 ...                             ...                   ...
# blapme1              -1                              -1                    -1
# blalen9              -1                              -1                    -1
# blapdc103            -1                              -1                    -1
# blaact66             -1                              -1                    -1
# blaact55             -1                              -1                    -1
#
#            chloramphenicol  ...  imipenem-relebactam  erythromycin  \
# blapdc19b               -1  ...                   -1            -1
# ant6ia                  -1  ...                   -1            -1
# blaoxa120               -1  ...                   -1            -1
# mefc                    -1  ...                   -1            -1
# blaec                   -1  ...                   -1            -1
# ...                    ...  ...                  ...           ...
# blapme1                 -1  ...                   -1            -1
# blalen9                 -1  ...                   -1            -1
# blapdc103               -1  ...                   -1            -1
# blaact66                -1  ...                   -1            -1
# blaact55                -1  ...                   -1            -1
#
#            carbenicillin  mupirocin  enrofloxacin  colistin  plazomicin  \
# blapdc19b             -1         -1            -1        -1          -1
# ant6ia                -1         -1            -1        -1          -1
# blaoxa120             -1         -1            -1        -1          -1
# mefc                  -1         -1            -1        -1          -1
# blaec                 -1         -1            -1        -1          -1
# ...                  ...        ...           ...       ...         ...
# blapme1               -1         -1            -1        -1          -1
# blalen9               -1         -1            -1        -1          -1
# blapdc103             -1         -1            -1        -1          -1
# blaact66              -1         -1            -1        -1          -1
# blaact55              -1         -1            -1        -1          -1
#
#            ciprofloxacin  vancomycin  Imipenem-EDTA-PA
# blapdc19b             -1          -1                -1
# ant6ia                -1          -1                -1
# blaoxa120             -1          -1                -1
# mefc                  -1          -1                -1
# blaec                 -1          -1                -1
# ...                  ...         ...               ...
# blapme1               -1          -1                -1
# blalen9               -1          -1                -1
# blapdc103             -1          -1                -1
# blaact66              -1          -1                -1
# blaact55              -1          -1                -1
#
# [968 rows x 114 columns]

# %%
gene_antibiotic_df.shape
# Out:
# (968, 114)

# %%
from collections import Counter

antibiotic_counts = Counter(unique_all_antibiotics)

# Find the duplicates (drugs with count greater than 1)
duplicates = [antibiotic for antibiotic, count in antibiotic_counts.items() if count > 1]

if len(duplicates) > 0:
    # Duplicates are present in 'unique_all_antibiotics'
    print("Duplicate drugs:", duplicates)
else:
    # No duplicates found
    print("No duplicates.")
print(len(unique_all_antibiotics))
# Out:
# No duplicates.
# 114

# %%
gene_antibiotic_df.to_csv("Empty_Gene_Antibiotic.csv", index=True, index_label=False)

# %% [markdown]
# ***********************************************

# %% [markdown]
# ### run from here

# %%
# def gene_per_drug(drug):
#     drug_df = df[df['drug'] == drug]
#     unique_genes = set()
#     for genes in drug_df['AMR genotypes'].str.split(', '):
#         unique_genes.update(genes)
#     return drug_df, unique_genes

# %%
df = pd.read_csv('BasicData_clean.csv')
val_data = pd.read_csv('val_data.csv')
gene_antibiotic_df = pd.read_csv('Empty_Gene_Antibiotic.csv')
anti_family = clean_gene(anti_family,'gene')

# %%
gene_antibiotic_df
# Out:
#            ceftiofur  cefalexin  doxycycline  neomycin  ticarcillin  rifampin  \
# blapdc19b         -1         -1           -1        -1           -1        -1
# ant6ia            -1         -1           -1        -1           -1        -1
# blaoxa120         -1         -1           -1        -1           -1        -1
# mefc              -1         -1           -1        -1           -1        -1
# blaec             -1         -1           -1        -1           -1        -1
# ...              ...        ...          ...       ...          ...       ...
# blapme1           -1         -1           -1        -1           -1        -1
# blalen9           -1         -1           -1        -1           -1        -1
# blapdc103         -1         -1           -1        -1           -1        -1
# blaact66          -1         -1           -1        -1           -1        -1
# blaact55          -1         -1           -1        -1           -1        -1
#
#            zoliflodacin  fosfomycin-glucose-6-phosphate  ampicillin-sulbactam  \
# blapdc19b            -1                              -1                    -1
# ant6ia               -1                              -1                    -1
# blaoxa120            -1                              -1                    -1
# mefc                 -1                              -1                    -1
# blaec                -1                              -1                    -1
# ...                 ...                             ...                   ...
# blapme1              -1                              -1                    -1
# blalen9              -1                              -1                    -1
# blapdc103            -1                              -1                    -1
# blaact66             -1                              -1                    -1
# blaact55             -1                              -1                    -1
#
#            chloramphenicol  ...  imipenem-relebactam  erythromycin  \
# blapdc19b               -1  ...                   -1            -1
# ant6ia                  -1  ...                   -1            -1
# blaoxa120               -1  ...                   -1            -1
# mefc                    -1  ...                   -1            -1
# blaec                   -1  ...                   -1            -1
# ...                    ...  ...                  ...           ...
# blapme1                 -1  ...                   -1            -1
# blalen9                 -1  ...                   -1            -1
# blapdc103               -1  ...                   -1            -1
# blaact66                -1  ...                   -1            -1
# blaact55                -1  ...                   -1            -1
#
#            carbenicillin  mupirocin  enrofloxacin  colistin  plazomicin  \
# blapdc19b             -1         -1            -1        -1          -1
# ant6ia                -1         -1            -1        -1          -1
# blaoxa120             -1         -1            -1        -1          -1
# mefc                  -1         -1            -1        -1          -1
# blaec                 -1         -1            -1        -1          -1
# ...                  ...        ...           ...       ...         ...
# blapme1               -1         -1            -1        -1          -1
# blalen9               -1         -1            -1        -1          -1
# blapdc103             -1         -1            -1        -1          -1
# blaact66              -1         -1            -1        -1          -1
# blaact55              -1         -1            -1        -1          -1
#
#            ciprofloxacin  vancomycin  Imipenem-EDTA-PA
# blapdc19b             -1          -1                -1
# ant6ia                -1          -1                -1
# blaoxa120             -1          -1                -1
# mefc                  -1          -1                -1
# blaec                 -1          -1                -1
# ...                  ...         ...               ...
# blapme1               -1          -1                -1
# blalen9               -1          -1                -1
# blapdc103             -1          -1                -1
# blaact66              -1          -1                -1
# blaact55              -1          -1                -1
#
# [968 rows x 114 columns]

# %%
def gene_per_drug(drug):
    drug_df = df[df['drug'] == drug]
    unique_genes = set()
    for genes in drug_df['AMR genotypes'].str.split(', '):
        unique_genes.update(genes)
    return drug_df,unique_genes
    # # Get unique #Organism group values
    # organism_groups = drug_df['#Organism group'].unique()
    #
    # # Initialize empty lists for train_df and test_df
    # train_dfs = []
    # test_dfs = []
    #
    # # Iterate over #Organism groups
    # for group in organism_groups:
    #     group_df = drug_df[drug_df['#Organism group'] == group]
    #
    #     if len(group_df) > 1:
    #         group_train_df, group_test_df = train_test_split(group_df, test_size=0.2, random_state=42)
    #     else:
    #         group_train_df = group_df
    #         group_test_df = group_df
    #
    #     train_dfs.append(group_train_df)
    #     test_dfs.append(group_test_df)
    #
    # # Concatenate the train and test dataframes for all groups
    # train_df = pd.concat(train_dfs)
    # test_df = pd.concat(test_dfs)
    #
    # return train_df, test_df, unique_genes

# Rest of the code remains the same

# %%
def relevant_val_df(drug,unique_genes):
    relevant_df = val_data[(val_data['Subclass'] == drug) & (val_data['Gene family'].isin(unique_genes))]
    if relevant_df.shape[0]>1 :
        return relevant_df
    return None

# %%
# def create_gene_df(drug_df,val_df, unique_genes):
#     gene_arrays = []
#     labels = []
#
#     for idx, row in drug_df.iterrows():
#         gene_array = np.zeros(len(unique_genes), dtype=int)
#         genes = row['AMR genotypes'].split(', ')
#         for gene in genes:
#             gene_index = list(unique_genes).index(gene)
#             gene_array[gene_index] = 1
#
#         gene_arrays.append(gene_array.tolist())
#         labels.append(row['resistance'])
#
#     gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
#     gene_df['label'] = labels
#
#     if val_df is not None:
#         for idx, row in val_df.iterrows():
#             gene_array = np.zeros(len(unique_genes), dtype=int)
#             gene = row['Gene family']
#             gene_index = list(unique_genes).index(gene)
#             gene_array[gene_index] = 1
#
#             gene_arrays.append(gene_array.tolist())
#             labels.append(1)
#
#         gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
#         gene_df['label'] = labels
#
#     return gene_df.sample(frac=1).reset_index(drop=True)

# %%
def create_update_gene_df(drug_df, unique_genes, drug):
    gene_arrays = []
    labels = []
    drug_r = set(anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist())
    for _, row in drug_df.iterrows():
        genes = row['AMR genotypes'].split(', ')
        label = row['resistance']
        gene_array = np.zeros(len(unique_genes), dtype=int)

        for gene in genes:
            gene_index = list(unique_genes).index(gene)
            if gene in drug_r:
                gene_array[gene_index] = 1

        gene_arrays.append(gene_array.tolist())
        labels.append(label)
    gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
    gene_df['label'] = labels

    # if val_df is not None:
    #     for idx, row in val_df.iterrows():
    #         gene_array = np.zeros(len(unique_genes), dtype=int)
    #         gene = row['Gene family']
    #         gene_index = list(unique_genes).index(gene)
    #         gene_array[gene_index] = 1
    #
    #         gene_arrays.append(gene_array.tolist())
    #         labels.append(1)
    #
    #     gene_df = pd.DataFrame(gene_arrays, columns=unique_genes)
    #     gene_df['label'] = labels

    zero_col = [col for col in gene_df.columns if col not in drug_r and col != 'label']
    gene_df = gene_df.drop(zero_col, axis=1)
    # if len(zero_col) == 0:
    #     zero_col = [col for col in gene_df.columns if col not in drug_r and col != 'label']
    # else:
    #     zero_col = [col for col in zero_col if col not in drug_r and col != 'label']
    # gene_df = gene_df.drop(zero_col, axis=1)
    return gene_df.sample(frac=1).reset_index(drop=True)

# %%
# def update_df(df, drug, anti_family, zero_col):
#     # Get the list of genes for which the antibiotic is the specified drug
#     drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
#     drug_s = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] != 1) & (anti_family['S'] == 's'), 'gene'].tolist()
#
#     # Iterate over each row
#     for index, row in df.iterrows():
#         # Iterate over each column
#         for column in df.columns:
#             gene = str(column)
#             if gene == "label":
#                 continue
#             # Check if the gene is not in the list of drug genes and label is 1 or 0.5
#             if ((gene not in drug_r) or (gene in drug_s)) and (row['label'] == 1):
#                 # Set the value to 0 if the condition is met
#                 df.loc[index, column] = 0
#
#             # Check if the gene is in the list of drug genes and label is 0
#             if (gene in drug_r) and (row['label'] == 0):
#                 df.loc[index, column] = 0
#
#             if (gene in drug_s) and (row['label'] == 0):
#                 df.loc[index, column] = 1
#
#
#
#     if len(zero_col)==0:
#         zero_col = df.columns[df.eq(0).all(axis=0)]
#     df = df.drop(zero_col, axis=1)
#     return df, zero_col

# %%
def Model_deep(drug_train_for_model, epochs, batch_size):
    # Assuming your DataFrame with gene features and labels is named `oxacillin_df_for_model`
    # Split the data into training features (genes) and labels
    X_train = drug_train_for_model.drop('label', axis=1).values
    y_train = drug_train_for_model['label'].values


    # Define the neural network model
    model = keras.Sequential()
    model.add(keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dense(16, activation='relu'))
    model.add(keras.layers.Dense(1, activation='sigmoid'))  # Sigmoid activation for probability between 0 and 1

    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['mse'])

    # Train the model
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

    # Make predictions on the training data
    pred = model.predict(X_train)

    # Display loss and mse (mse on training data, as we are not using separate test data)
    loss, mse = model.evaluate(X_train, y_train)
    print('Loss:', loss)
    print('Mean Squared Error:', mse)
    print('Shape of predictions:', pred.shape)
    print('Shape of y_train:', y_train.shape)

    # Make predictions
    return y_train, pred, model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

def Model(drug_train_for_model, drug_test_for_model):
    # Split the data into training features (genes) and labels
    X_train = drug_train_for_model.drop('label', axis=1).values
    y_train = drug_train_for_model['label'].values

    # Split the data into testing features (genes) and labels
    X_test = drug_test_for_model.drop('label', axis=1).values
    y_test = drug_test_for_model['label'].values

    # Initialize the model
    model = RandomForestRegressor(n_estimators=100, random_state=0)

    # Train the model
    model.fit(X_train, y_train)

    # Predict the resistance score
    y_pred = model.predict(X_test)

    # Compute mean squared error
    mse = mean_squared_error(y_test, y_pred)

    print('Mean Squared Error:', mse)
    print('len of pred:', y_pred.shape, 'y_test:', y_test.shape)

    # Make predictions
    return y_test, y_pred, model

# %%
def evaluation(y_test, predictions, drug):
    # Calculate mean squared error
    mse = mean_squared_error(y_test, predictions)

    # Calculate mean absolute error
    mae = mean_absolute_error(y_test, predictions)

    # Calculate R^2 score
    r2 = r2_score(y_test, predictions)


    print('Mean Squared Error:', mse)
    print('Mean Absolute Error:', mae)
    print('R^2 Score:', r2)
    return mse, mae, r2

# %%
def Create_df_one_gene(drug_df_for_model):
    # Extract the column names (excluding the label column)
    column_names = drug_df_for_model.columns[:-1]

    # Create a new DataFrame with zeros
    df_one_gene = pd.DataFrame(0, index=np.arange(len(column_names)), columns=column_names)

    # Set the value at the corresponding index position in each row
    for i in range(len(column_names)):
        df_one_gene.iloc[i, i] = 1

    # Display the new DataFrame
    return df_one_gene

# %%
# it will save the drugs with empty df_gene
problematic_drugs = []

# %%
def PredR_Antibiotic(drug,drug_val_dict):
    print('************************\n', drug)
    drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
    drug_df,drug_genes = gene_per_drug(drug)
    drug_train_for_model = create_update_gene_df(drug_df,list(drug_genes), drug)
    val_drug= relevant_val_df(drug, drug_genes)
    if val_drug is not None:
        drug_val_dict[drug] = val_drug
    y_train, predictions, model = Model_deep(drug_train_for_model, 40, 10)
    df_gene = Create_df_one_gene(drug_train_for_model)
    if df_gene.shape[1]>1:
     pred = model.predict(df_gene)
    else:
        problematic_drugs.append(drug)

    for col in drug_genes:
        if (df_gene.shape[1]>1) and (col in drug_r):
         gene_antibiotic_df.loc[col, drug] = pred[df_gene.columns.get_loc(col)]
        else:
          gene_antibiotic_df.loc[col, drug] = 0.0

# %%
antibiotic_few_samples = []
antibiotic_done = []
drug_val_dict = {}
for antibiotic in unique_all_antibiotics:
    if len(df[df['drug'] == antibiotic]) < 50:
        antibiotic_few_samples.append(antibiotic)
        continue   
    PredR_Antibiotic(antibiotic,drug_val_dict)
    antibiotic_done.append(antibiotic)
    gene_antibiotic_df.to_csv("Gene_Antibiotic_26_07.csv", index=True, index_label=False)
# Out:
# ************************
#  ceftiofur
# Epoch 1/40
# 486/486 [==============================] - 3s 3ms/step - loss: 0.4420 - mse: 0.1340
# Epoch 2/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4329 - mse: 0.1303
# Epoch 3/40
# 486/486 [==============================] - 1s 3ms/step - loss: 0.4336 - mse: 0.1303
# Epoch 4/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4327 - mse: 0.1301
# Epoch 5/40
# 486/486 [==============================] - 1s 3ms/step - loss: 0.4304 - mse: 0.1295
# Epoch 6/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4327 - mse: 0.1301
# Epoch 7/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4302 - mse: 0.1294
# Epoch 8/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4317 - mse: 0.1298
# Epoch 9/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4314 - mse: 0.1296
# Epoch 10/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4310 - mse: 0.1296
# Epoch 11/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4309 - mse: 0.1295
# Epoch 12/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4310 - mse: 0.1296
# Epoch 13/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4306 - mse: 0.1295
# Epoch 14/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4307 - mse: 0.1295
# Epoch 15/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4293 - mse: 0.1291
# Epoch 16/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4303 - mse: 0.1294
# Epoch 17/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4301 - mse: 0.1293
# Epoch 18/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4298 - mse: 0.1292
# Epoch 19/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4307 - mse: 0.1294
# Epoch 20/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4311 - mse: 0.1296
# Epoch 21/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4299 - mse: 0.1293
# Epoch 22/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4310 - mse: 0.1296
# Epoch 23/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4296 - mse: 0.1292
# Epoch 24/40
# 486/486 [==============================] - 1s 2ms/step - loss: 0.4302 - mse: 0.1294
# Epoch 25/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4303 - mse: 0.1294
# Epoch 26/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4306 - mse: 0.1295
# Epoch 27/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4301 - mse: 0.1293
# Epoch 28/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4301 - mse: 0.1294
# Epoch 29/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4301 - mse: 0.1293
# Epoch 30/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4303 - mse: 0.1294
# Epoch 31/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4300 - mse: 0.1293
# Epoch 32/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4294 - mse: 0.1292
# Epoch 33/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4293 - mse: 0.1291
# Epoch 34/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4298 - mse: 0.1293
# Epoch 35/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4300 - mse: 0.1293
# Epoch 36/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4299 - mse: 0.1293
# Epoch 37/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4307 - mse: 0.1295
# Epoch 38/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4302 - mse: 0.1294
# Epoch 39/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4302 - mse: 0.1294
# Epoch 40/40
# 486/486 [==============================] - 1s 1ms/step - loss: 0.4293 - mse: 0.1291
# 152/152 [==============================] - 0s 908us/step
# 152/152 [==============================] - 0s 990us/step - loss: 0.4287 - mse: 0.1289
# Loss: 0.42866864800453186
# Mean Squared Error: 0.128923699259758
# Shape of predictions: (4851, 1)
# Shape of y_train: (4851,)
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  doxycycline
# Epoch 1/40
# 24/24 [==============================] - 1s 1ms/step - loss: 0.6323 - mse: 0.1768
# Epoch 2/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5492 - mse: 0.1385
# Epoch 3/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5101 - mse: 0.1219
# Epoch 4/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4807 - mse: 0.1109
# Epoch 5/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4716 - mse: 0.1079
# Epoch 6/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4656 - mse: 0.1059
# Epoch 7/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4590 - mse: 0.1042
# Epoch 8/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4600 - mse: 0.1049
# Epoch 9/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4667 - mse: 0.1074
# Epoch 10/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4582 - mse: 0.1044
# Epoch 11/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4608 - mse: 0.1056
# Epoch 12/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4560 - mse: 0.1047
# Epoch 13/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4502 - mse: 0.1022
# Epoch 14/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4535 - mse: 0.1035
# Epoch 15/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4496 - mse: 0.1022
# Epoch 16/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4528 - mse: 0.1037
# Epoch 17/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4522 - mse: 0.1028
# Epoch 18/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4544 - mse: 0.1044
# Epoch 19/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4508 - mse: 0.1030
# Epoch 20/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4447 - mse: 0.1010
# Epoch 21/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4475 - mse: 0.1019
# Epoch 22/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4437 - mse: 0.1007
# Epoch 23/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4413 - mse: 0.1002
# Epoch 24/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4464 - mse: 0.1016
# Epoch 25/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4461 - mse: 0.1015
# Epoch 26/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4447 - mse: 0.1017
# Epoch 27/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4464 - mse: 0.1019
# Epoch 28/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4507 - mse: 0.1030
# Epoch 29/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4501 - mse: 0.1027
# Epoch 30/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4447 - mse: 0.1010
# Epoch 31/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4476 - mse: 0.1022
# Epoch 32/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4486 - mse: 0.1032
# Epoch 33/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4468 - mse: 0.1025
# Epoch 34/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4447 - mse: 0.1018
# Epoch 35/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4411 - mse: 0.1003
# Epoch 36/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4450 - mse: 0.1013
# Epoch 37/40
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4394 - mse: 0.0999
# Epoch 38/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4400 - mse: 0.0999
# Epoch 39/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4601 - mse: 0.1081
# Epoch 40/40
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4413 - mse: 0.1003
# 8/8 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4370 - mse: 0.0988
# Loss: 0.43704402446746826
# Mean Squared Error: 0.09882567822933197
# Shape of predictions: (231, 1)
# Shape of y_train: (231,)
# 1/1 [==============================] - 0s 19ms/step
# ************************
#  rifampin
# Epoch 1/40
# 83/83 [==============================] - 1s 1ms/step - loss: 0.4550 - mse: 0.1408
# Epoch 2/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2296 - mse: 0.0540
# Epoch 3/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2213 - mse: 0.0515
# Epoch 4/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2194 - mse: 0.0507
# Epoch 5/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2169 - mse: 0.0500
# Epoch 6/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2158 - mse: 0.0499
# Epoch 7/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2125 - mse: 0.0491
# Epoch 8/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2169 - mse: 0.0507
# Epoch 9/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2134 - mse: 0.0495
# Epoch 10/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2144 - mse: 0.0495
# Epoch 11/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2119 - mse: 0.0493
# Epoch 12/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2120 - mse: 0.0490
# Epoch 13/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2145 - mse: 0.0498
# Epoch 14/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2145 - mse: 0.0494
# Epoch 15/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2125 - mse: 0.0491
# Epoch 16/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2119 - mse: 0.0489
# Epoch 17/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2123 - mse: 0.0491
# Epoch 18/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2130 - mse: 0.0494
# Epoch 19/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2128 - mse: 0.0490
# Epoch 20/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2120 - mse: 0.0490
# Epoch 21/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2132 - mse: 0.0493
# Epoch 22/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2108 - mse: 0.0487
# Epoch 23/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2138 - mse: 0.0489
# Epoch 24/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2113 - mse: 0.0490
# Epoch 25/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2113 - mse: 0.0488
# Epoch 26/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2147 - mse: 0.0493
# Epoch 27/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2091 - mse: 0.0485
# Epoch 28/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2130 - mse: 0.0490
# Epoch 29/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2114 - mse: 0.0489
# Epoch 30/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2102 - mse: 0.0487
# Epoch 31/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2123 - mse: 0.0492
# Epoch 32/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2113 - mse: 0.0489
# Epoch 33/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2104 - mse: 0.0488
# Epoch 34/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2122 - mse: 0.0490
# Epoch 35/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2119 - mse: 0.0491
# Epoch 36/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2114 - mse: 0.0485
# Epoch 37/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2105 - mse: 0.0487
# Epoch 38/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2113 - mse: 0.0487
# Epoch 39/40
# 83/83 [==============================] - 0s 2ms/step - loss: 0.2111 - mse: 0.0489
# Epoch 40/40
# 83/83 [==============================] - 0s 1ms/step - loss: 0.2104 - mse: 0.0486
# 26/26 [==============================] - 0s 961us/step
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2076 - mse: 0.0481
# Loss: 0.20757687091827393
# Mean Squared Error: 0.04805102199316025
# Shape of predictions: (825, 1)
# Shape of y_train: (825,)
# 1/1 [==============================] - 0s 18ms/step
# ************************
#  zoliflodacin
# Epoch 1/40
# 46/46 [==============================] - 1s 1ms/step - loss: 0.6931 - mse: 5.5108e-04
# Epoch 2/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5054e-04
# Epoch 3/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5079e-04
# Epoch 4/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5074e-04
# Epoch 5/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5048e-04
# Epoch 6/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5074e-04
# Epoch 7/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5053e-04
# Epoch 8/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5060e-04
# Epoch 9/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5032e-04
# Epoch 10/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5082e-04
# Epoch 11/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5053e-04
# Epoch 12/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5072e-04
# Epoch 13/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5039e-04
# Epoch 14/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5103e-04
# Epoch 15/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5083e-04
# Epoch 16/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5042e-04
# Epoch 17/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5071e-04
# Epoch 18/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5078e-04
# Epoch 19/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5076e-04
# Epoch 20/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5028e-04
# Epoch 21/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5022e-04
# Epoch 22/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5052e-04
# Epoch 23/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5074e-04
# Epoch 24/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5057e-04
# Epoch 25/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5074e-04
# Epoch 26/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5035e-04
# Epoch 27/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5085e-04
# Epoch 28/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5076e-04
# Epoch 29/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5067e-04
# Epoch 30/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5072e-04
# Epoch 31/40
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.5089e-04
# Epoch 32/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5077e-04
# Epoch 33/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5097e-04
# Epoch 34/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5067e-04
# Epoch 35/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5069e-04
# Epoch 36/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5070e-04
# Epoch 37/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5079e-04
# Epoch 38/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6932 - mse: 5.5256e-04
# Epoch 39/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5087e-04
# Epoch 40/40
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.5059e-04
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 5.4948e-04
# Loss: 0.6931447982788086
# Mean Squared Error: 0.0005494792712852359
# Shape of predictions: (454, 1)
# Shape of y_train: (454,)
# ************************
#  ampicillin-sulbactam
# Epoch 1/40
# 184/184 [==============================] - 1s 1ms/step - loss: 0.6102 - mse: 0.1779
# Epoch 2/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5895 - mse: 0.1703
# Epoch 3/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5880 - mse: 0.1697
# Epoch 4/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5868 - mse: 0.1691
# Epoch 5/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5856 - mse: 0.1688
# Epoch 6/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5852 - mse: 0.1686
# Epoch 7/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5844 - mse: 0.1686
# Epoch 8/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5844 - mse: 0.1685
# Epoch 9/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5847 - mse: 0.1686
# Epoch 10/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5855 - mse: 0.1690
# Epoch 11/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5845 - mse: 0.1687
# Epoch 12/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5835 - mse: 0.1685
# Epoch 13/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5837 - mse: 0.1686
# Epoch 14/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5835 - mse: 0.1683
# Epoch 15/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5833 - mse: 0.1684
# Epoch 16/40
# 184/184 [==============================] - 0s 2ms/step - loss: 0.5837 - mse: 0.1686
# Epoch 17/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5841 - mse: 0.1685
# Epoch 18/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5840 - mse: 0.1685
# Epoch 19/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5833 - mse: 0.1683
# Epoch 20/40
# 184/184 [==============================] - 0s 2ms/step - loss: 0.5823 - mse: 0.1682
# Epoch 21/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5837 - mse: 0.1684
# Epoch 22/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5845 - mse: 0.1687
# Epoch 23/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5833 - mse: 0.1685
# Epoch 24/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5832 - mse: 0.1681
# Epoch 25/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5830 - mse: 0.1682
# Epoch 26/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5837 - mse: 0.1684
# Epoch 27/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5830 - mse: 0.1682
# Epoch 28/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5823 - mse: 0.1684
# Epoch 29/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5830 - mse: 0.1682
# Epoch 30/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5831 - mse: 0.1683
# Epoch 31/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5830 - mse: 0.1682
# Epoch 32/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5830 - mse: 0.1683
# Epoch 33/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5824 - mse: 0.1681
# Epoch 34/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5825 - mse: 0.1680
# Epoch 35/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5828 - mse: 0.1681
# Epoch 36/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5835 - mse: 0.1684
# Epoch 37/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5828 - mse: 0.1683
# Epoch 38/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5820 - mse: 0.1681
# Epoch 39/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5824 - mse: 0.1679
# Epoch 40/40
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5813 - mse: 0.1683
# 58/58 [==============================] - 0s 922us/step
# 58/58 [==============================] - 0s 1ms/step - loss: 0.5813 - mse: 0.1680
# Loss: 0.5812885761260986
# Mean Squared Error: 0.16801238059997559
# Shape of predictions: (1834, 1)
# Shape of y_train: (1834,)
# 1/1 [==============================] - 0s 16ms/step
# ************************
#  chloramphenicol
# Epoch 1/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0912 - mse: 0.0172
# Epoch 2/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0733 - mse: 0.0115
# Epoch 3/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0722 - mse: 0.0112
# Epoch 4/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0713 - mse: 0.0109
# Epoch 5/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0706 - mse: 0.0108
# Epoch 6/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0704 - mse: 0.0106
# Epoch 7/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0703 - mse: 0.0107
# Epoch 8/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0695 - mse: 0.0104
# Epoch 9/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0693 - mse: 0.0104
# Epoch 10/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0694 - mse: 0.0105
# Epoch 11/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0688 - mse: 0.0103
# Epoch 12/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0691 - mse: 0.0104
# Epoch 13/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0688 - mse: 0.0103
# Epoch 14/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0685 - mse: 0.0103
# Epoch 15/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0686 - mse: 0.0103
# Epoch 16/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0685 - mse: 0.0102
# Epoch 17/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0684 - mse: 0.0102
# Epoch 18/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0690 - mse: 0.0103
# Epoch 19/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0685 - mse: 0.0103
# Epoch 20/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0682 - mse: 0.0101
# Epoch 21/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0683 - mse: 0.0102
# Epoch 22/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0681 - mse: 0.0102
# Epoch 23/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0683 - mse: 0.0102
# Epoch 24/40
# 1228/1228 [==============================] - 2s 2ms/step - loss: 0.0681 - mse: 0.0102
# Epoch 25/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0678 - mse: 0.0102
# Epoch 26/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0680 - mse: 0.0101
# Epoch 27/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0681 - mse: 0.0102
# Epoch 28/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0678 - mse: 0.0102
# Epoch 29/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0678 - mse: 0.0102
# Epoch 30/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0681 - mse: 0.0102
# Epoch 31/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0675 - mse: 0.0101
# Epoch 32/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0679 - mse: 0.0101
# Epoch 33/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0675 - mse: 0.0101
# Epoch 34/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0676 - mse: 0.0101
# Epoch 35/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0676 - mse: 0.0101
# Epoch 36/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0675 - mse: 0.0100
# Epoch 37/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0680 - mse: 0.0101
# Epoch 38/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0675 - mse: 0.0101
# Epoch 39/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0675 - mse: 0.0101
# Epoch 40/40
# 1228/1228 [==============================] - 2s 1ms/step - loss: 0.0679 - mse: 0.0101
# 384/384 [==============================] - 0s 840us/step
# 384/384 [==============================] - 0s 963us/step - loss: 0.0660 - mse: 0.0099
# Loss: 0.066001757979393
# Mean Squared Error: 0.00985333975404501
# Shape of predictions: (12272, 1)
# Shape of y_train: (12272,)
# 1/1 [==============================] - 0s 16ms/step
# ************************
#  ceftolozane-tazobactam
# Epoch 1/40
# 45/45 [==============================] - 1s 1ms/step - loss: 0.6822 - mse: 0.2324
# Epoch 2/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.6403 - mse: 0.2126
# Epoch 3/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.6092 - mse: 0.1989
# Epoch 4/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5928 - mse: 0.1919
# Epoch 5/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5866 - mse: 0.1894
# Epoch 6/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5798 - mse: 0.1868
# Epoch 7/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5735 - mse: 0.1846
# Epoch 8/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5681 - mse: 0.1825
# Epoch 9/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5699 - mse: 0.1840
# Epoch 10/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5688 - mse: 0.1830
# Epoch 11/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5629 - mse: 0.1809
# Epoch 12/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5608 - mse: 0.1803
# Epoch 13/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5602 - mse: 0.1803
# Epoch 14/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5627 - mse: 0.1818
# Epoch 15/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5641 - mse: 0.1823
# Epoch 16/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5594 - mse: 0.1802
# Epoch 17/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5561 - mse: 0.1793
# Epoch 18/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5580 - mse: 0.1795
# Epoch 19/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5555 - mse: 0.1793
# Epoch 20/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5535 - mse: 0.1782
# Epoch 21/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5542 - mse: 0.1786
# Epoch 22/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5538 - mse: 0.1783
# Epoch 23/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5523 - mse: 0.1779
# Epoch 24/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5520 - mse: 0.1772
# Epoch 25/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5525 - mse: 0.1780
# Epoch 26/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5490 - mse: 0.1765
# Epoch 27/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5538 - mse: 0.1793
# Epoch 28/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5513 - mse: 0.1773
# Epoch 29/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5509 - mse: 0.1774
# Epoch 30/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5529 - mse: 0.1784
# Epoch 31/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5511 - mse: 0.1769
# Epoch 32/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5494 - mse: 0.1770
# Epoch 33/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5469 - mse: 0.1761
# Epoch 34/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5485 - mse: 0.1765
# Epoch 35/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5484 - mse: 0.1767
# Epoch 36/40
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5474 - mse: 0.1764
# Epoch 37/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5500 - mse: 0.1776
# Epoch 38/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5494 - mse: 0.1772
# Epoch 39/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5498 - mse: 0.1773
# Epoch 40/40
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5473 - mse: 0.1758
# 15/15 [==============================] - 0s 1ms/step
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5403 - mse: 0.1735
# Loss: 0.5403205752372742
# Mean Squared Error: 0.17350199818611145
# Shape of predictions: (449, 1)
# Shape of y_train: (449,)
# 1/1 [==============================] - 0s 19ms/step
# ************************
#  ampicillin
# Epoch 1/40
# 1638/1638 [==============================] - 3s 2ms/step - loss: 0.5839 - mse: 0.1994
# Epoch 2/40
# 1638/1638 [==============================] - 3s 2ms/step - loss: 0.5794 - mse: 0.1976
# Epoch 3/40
# 1638/1638 [==============================] - 3s 2ms/step - loss: 0.5794 - mse: 0.1977
# Epoch 4/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5794 - mse: 0.1976
# Epoch 5/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5794 - mse: 0.1977
# Epoch 6/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5788 - mse: 0.1975
# Epoch 7/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5787 - mse: 0.1975
# Epoch 8/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5786 - mse: 0.1975
# Epoch 9/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5788 - mse: 0.1976
# Epoch 10/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5789 - mse: 0.1976
# Epoch 11/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5783 - mse: 0.1974
# Epoch 12/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5788 - mse: 0.1976
# Epoch 13/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5785 - mse: 0.1975
# Epoch 14/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5783 - mse: 0.1974
# Epoch 15/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5783 - mse: 0.1973
# Epoch 16/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5783 - mse: 0.1974
# Epoch 17/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5785 - mse: 0.1974
# Epoch 18/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5782 - mse: 0.1973
# Epoch 19/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5782 - mse: 0.1974
# Epoch 20/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5781 - mse: 0.1974
# Epoch 21/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5789 - mse: 0.1975
# Epoch 22/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5779 - mse: 0.1974
# Epoch 23/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5780 - mse: 0.1973
# Epoch 24/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5781 - mse: 0.1973
# Epoch 25/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5780 - mse: 0.1974
# Epoch 26/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5779 - mse: 0.1973
# Epoch 27/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5776 - mse: 0.1972
# Epoch 28/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5784 - mse: 0.1974
# Epoch 29/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5783 - mse: 0.1974
# Epoch 30/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5779 - mse: 0.1973
# Epoch 31/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5777 - mse: 0.1972
# Epoch 32/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5775 - mse: 0.1972
# Epoch 33/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5782 - mse: 0.1974
# Epoch 34/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5773 - mse: 0.1972
# Epoch 35/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5780 - mse: 0.1973
# Epoch 36/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5779 - mse: 0.1973
# Epoch 37/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5777 - mse: 0.1973
# Epoch 38/40
# 1638/1638 [==============================] - 2s 2ms/step - loss: 0.5776 - mse: 0.1972
# Epoch 39/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5777 - mse: 0.1972
# Epoch 40/40
# 1638/1638 [==============================] - 2s 1ms/step - loss: 0.5780 - mse: 0.1973
# 512/512 [==============================] - 1s 1ms/step
# 512/512 [==============================] - 1s 952us/step - loss: 0.5770 - mse: 0.1971
# Loss: 0.5770450830459595
# Mean Squared Error: 0.19710101187229156
# Shape of predictions: (16371, 1)
# Shape of y_train: (16371,)
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  streptomycin
# Epoch 1/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2463 - mse: 0.0651
# Epoch 2/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2136 - mse: 0.0539
# Epoch 3/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2116 - mse: 0.0531
# Epoch 4/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2111 - mse: 0.0529
# Epoch 5/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2107 - mse: 0.0528
# Epoch 6/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2096 - mse: 0.0526
# Epoch 7/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2094 - mse: 0.0523
# Epoch 8/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2089 - mse: 0.0522
# Epoch 9/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2092 - mse: 0.0524
# Epoch 10/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2076 - mse: 0.0520
# Epoch 11/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2088 - mse: 0.0522
# Epoch 12/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2074 - mse: 0.0520
# Epoch 13/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2083 - mse: 0.0521
# Epoch 14/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2077 - mse: 0.0520
# Epoch 15/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2073 - mse: 0.0520
# Epoch 16/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2074 - mse: 0.0519
# Epoch 17/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2070 - mse: 0.0519
# Epoch 18/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2067 - mse: 0.0519
# Epoch 19/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2067 - mse: 0.0518
# Epoch 20/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2072 - mse: 0.0518
# Epoch 21/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2062 - mse: 0.0516
# Epoch 22/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2064 - mse: 0.0517
# Epoch 23/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2057 - mse: 0.0514
# Epoch 24/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2064 - mse: 0.0516
# Epoch 25/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2064 - mse: 0.0516
# Epoch 26/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2061 - mse: 0.0517
# Epoch 27/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2059 - mse: 0.0516
# Epoch 28/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2057 - mse: 0.0516
# Epoch 29/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2058 - mse: 0.0516
# Epoch 30/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2056 - mse: 0.0517
# Epoch 31/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2058 - mse: 0.0516
# Epoch 32/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2056 - mse: 0.0516
# Epoch 33/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2055 - mse: 0.0515
# Epoch 34/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2054 - mse: 0.0515
# Epoch 35/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2057 - mse: 0.0516
# Epoch 36/40
# 1153/1153 [==============================] - 2s 2ms/step - loss: 0.2055 - mse: 0.0515
# Epoch 37/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2054 - mse: 0.0515
# Epoch 38/40
# 1153/1153 [==============================] - 2s 1ms/step - loss: 0.2055 - mse: 0.0515
# Epoch 39/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2053 - mse: 0.0515
# Epoch 40/40
# 1153/1153 [==============================] - 1s 1ms/step - loss: 0.2053 - mse: 0.0514
# 361/361 [==============================] - 0s 870us/step
# 361/361 [==============================] - 1s 1ms/step - loss: 0.2028 - mse: 0.0510
# Loss: 0.20279957354068756
# Mean Squared Error: 0.050988394767045975
# Shape of predictions: (11530, 1)
# Shape of y_train: (11530,)
# 2/2 [==============================] - 0s 3ms/step
# ************************
#  azithromycin
# Epoch 1/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0751 - mse: 0.0143
# Epoch 2/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0547 - mse: 0.0091
# Epoch 3/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0536 - mse: 0.0089
# Epoch 4/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0532 - mse: 0.0088
# Epoch 5/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0532 - mse: 0.0088
# Epoch 6/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0533 - mse: 0.0087
# Epoch 7/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0522 - mse: 0.0086
# Epoch 8/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0520 - mse: 0.0086
# Epoch 9/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0522 - mse: 0.0085
# Epoch 10/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0522 - mse: 0.0085
# Epoch 11/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0522 - mse: 0.0085
# Epoch 12/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0523 - mse: 0.0085
# Epoch 13/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0515 - mse: 0.0084
# Epoch 14/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0519 - mse: 0.0084
# Epoch 15/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0522 - mse: 0.0085
# Epoch 16/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0518 - mse: 0.0084
# Epoch 17/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0517 - mse: 0.0084
# Epoch 18/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0520 - mse: 0.0085
# Epoch 19/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0519 - mse: 0.0084
# Epoch 20/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0519 - mse: 0.0084
# Epoch 21/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0514 - mse: 0.0084
# Epoch 22/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0515 - mse: 0.0084
# Epoch 23/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0516 - mse: 0.0084
# Epoch 24/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0515 - mse: 0.0084
# Epoch 25/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0515 - mse: 0.0084
# Epoch 26/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0514 - mse: 0.0084
# Epoch 27/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0513 - mse: 0.0084
# Epoch 28/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0514 - mse: 0.0084
# Epoch 29/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0517 - mse: 0.0084
# Epoch 30/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0513 - mse: 0.0083
# Epoch 31/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0513 - mse: 0.0083
# Epoch 32/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0517 - mse: 0.0084
# Epoch 33/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0516 - mse: 0.0084
# Epoch 34/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0512 - mse: 0.0083
# Epoch 35/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0510 - mse: 0.0083
# Epoch 36/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0514 - mse: 0.0083
# Epoch 37/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0512 - mse: 0.0083
# Epoch 38/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0512 - mse: 0.0083
# Epoch 39/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0514 - mse: 0.0083
# Epoch 40/40
# 1234/1234 [==============================] - 2s 1ms/step - loss: 0.0512 - mse: 0.0083
# 386/386 [==============================] - 0s 879us/step
# 386/386 [==============================] - 1s 1ms/step - loss: 0.0514 - mse: 0.0083
# Loss: 0.0514214001595974
# Mean Squared Error: 0.008264031261205673
# Shape of predictions: (12339, 1)
# Shape of y_train: (12339,)
# 2/2 [==============================] - 0s 2ms/step
# ************************
#  cefazolin
# Epoch 1/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.6120 - mse: 0.2000
# Epoch 2/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5980 - mse: 0.1945
# Epoch 3/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5952 - mse: 0.1935
# Epoch 4/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5940 - mse: 0.1933
# Epoch 5/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5930 - mse: 0.1930
# Epoch 6/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5924 - mse: 0.1928
# Epoch 7/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5928 - mse: 0.1928
# Epoch 8/40
# 420/420 [==============================] - 1s 2ms/step - loss: 0.5916 - mse: 0.1925
# Epoch 9/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5904 - mse: 0.1921
# Epoch 10/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5909 - mse: 0.1923
# Epoch 11/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5904 - mse: 0.1922
# Epoch 12/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5903 - mse: 0.1921
# Epoch 13/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5908 - mse: 0.1924
# Epoch 14/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5911 - mse: 0.1925
# Epoch 15/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5906 - mse: 0.1923
# Epoch 16/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5899 - mse: 0.1922
# Epoch 17/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5902 - mse: 0.1922
# Epoch 18/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5898 - mse: 0.1921
# Epoch 19/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5894 - mse: 0.1920
# Epoch 20/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5905 - mse: 0.1923
# Epoch 21/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5897 - mse: 0.1922
# Epoch 22/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5899 - mse: 0.1922
# Epoch 23/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5898 - mse: 0.1920
# Epoch 24/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5898 - mse: 0.1921
# Epoch 25/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5893 - mse: 0.1920
# Epoch 26/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5893 - mse: 0.1919
# Epoch 27/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5900 - mse: 0.1922
# Epoch 28/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5899 - mse: 0.1920
# Epoch 29/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5896 - mse: 0.1920
# Epoch 30/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5892 - mse: 0.1919
# Epoch 31/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5897 - mse: 0.1922
# Epoch 32/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5891 - mse: 0.1919
# Epoch 33/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5898 - mse: 0.1922
# Epoch 34/40
# 420/420 [==============================] - 1s 2ms/step - loss: 0.5890 - mse: 0.1918
# Epoch 35/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5892 - mse: 0.1919
# Epoch 36/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5889 - mse: 0.1919
# Epoch 37/40
# 420/420 [==============================] - 1s 2ms/step - loss: 0.5887 - mse: 0.1918
# Epoch 38/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5896 - mse: 0.1920
# Epoch 39/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5893 - mse: 0.1920
# Epoch 40/40
# 420/420 [==============================] - 1s 1ms/step - loss: 0.5891 - mse: 0.1919
# 132/132 [==============================] - 0s 865us/step
# 132/132 [==============================] - 0s 1ms/step - loss: 0.5869 - mse: 0.1913
# Loss: 0.5868956446647644
# Mean Squared Error: 0.19125793874263763
# Shape of predictions: (4199, 1)
# Shape of y_train: (4199,)
# 1/1 [==============================] - 0s 18ms/step
# ************************
#  ticarcillin-clavulanic acid
# Epoch 1/40
# 8/8 [==============================] - 1s 2ms/step - loss: 0.6787 - mse: 0.2358
# Epoch 2/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5271 - mse: 0.1613
# Epoch 3/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4035 - mse: 0.1057
# Epoch 4/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2811 - mse: 0.0599
# Epoch 5/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1954 - mse: 0.0367
# Epoch 6/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1441 - mse: 0.0278
# Epoch 7/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1237 - mse: 0.0254
# Epoch 8/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1195 - mse: 0.0253
# Epoch 9/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1147 - mse: 0.0248
# Epoch 10/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1130 - mse: 0.0248
# Epoch 11/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1118 - mse: 0.0249
# Epoch 12/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1105 - mse: 0.0248
# Epoch 13/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1099 - mse: 0.0248
# Epoch 14/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1089 - mse: 0.0247
# Epoch 15/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1079 - mse: 0.0246
# Epoch 16/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1072 - mse: 0.0246
# Epoch 17/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1064 - mse: 0.0246
# Epoch 18/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1055 - mse: 0.0244
# Epoch 19/40
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1048 - mse: 0.0245
# Epoch 20/40
# ...
# Epoch 8/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4987 - mse: 0.0721
# Epoch 9/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4976 - mse: 0.0719
# Epoch 10/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4979 - mse: 0.0715
# Epoch 11/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4976 - mse: 0.0717
# Epoch 12/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4990 - mse: 0.0721
# Epoch 13/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4973 - mse: 0.0715
# Epoch 14/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4963 - mse: 0.0712
# Epoch 15/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4964 - mse: 0.0712
# Epoch 16/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4962 - mse: 0.0711
# Epoch 17/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4958 - mse: 0.0711
# Epoch 18/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4965 - mse: 0.0712
# Epoch 19/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4961 - mse: 0.0712
# Epoch 20/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4964 - mse: 0.0712
# Epoch 21/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4965 - mse: 0.0711
# Epoch 22/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4980 - mse: 0.0715
# Epoch 23/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4952 - mse: 0.0708
# Epoch 24/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4952 - mse: 0.0708
# Epoch 25/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4968 - mse: 0.0713
# Epoch 26/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4953 - mse: 0.0707
# Epoch 27/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4963 - mse: 0.0709
# Epoch 28/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4950 - mse: 0.0707
# Epoch 29/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4952 - mse: 0.0708
# Epoch 30/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4950 - mse: 0.0707
# Epoch 31/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4940 - mse: 0.0705
# Epoch 32/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4958 - mse: 0.0708
# Epoch 33/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4944 - mse: 0.0705
# Epoch 34/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4941 - mse: 0.0705
# Epoch 35/40
# 188/188 [==============================] - 0s 1ms/step - loss: 0.4961 - mse: 0.0711
# Epoch 36/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4934 - mse: 0.0702
# Epoch 37/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4950 - mse: 0.0709
# Epoch 38/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4946 - mse: 0.0707
# Epoch 39/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4944 - mse: 0.0706
# Epoch 40/40
# 188/188 [==============================] - 0s 2ms/step - loss: 0.4952 - mse: 0.0708
# 59/59 [==============================] - 0s 1ms/step
# 59/59 [==============================] - 0s 1ms/step - loss: 0.4925 - mse: 0.0699
# Loss: 0.4925389885902405
# Mean Squared Error: 0.06992824375629425
# Shape of predictions: (1877, 1)
# Shape of y_train: (1877,)
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  ciprofloxacin
# Epoch 1/40
# 2129/2129 [==============================] - 4s 1ms/step - loss: 0.4396 - mse: 0.1307
# Epoch 2/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4296 - mse: 0.1266
# Epoch 3/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4277 - mse: 0.1259
# Epoch 4/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4273 - mse: 0.1257
# Epoch 5/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4265 - mse: 0.1254
# Epoch 6/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4262 - mse: 0.1253
# Epoch 7/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4255 - mse: 0.1251
# Epoch 8/40
# 2129/2129 [==============================] - 3s 2ms/step - loss: 0.4255 - mse: 0.1250
# Epoch 9/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4250 - mse: 0.1249
# Epoch 10/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4251 - mse: 0.1249
# Epoch 11/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4250 - mse: 0.1249
# Epoch 12/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4248 - mse: 0.1248
# Epoch 13/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4244 - mse: 0.1247
# Epoch 14/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4246 - mse: 0.1248
# Epoch 15/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4240 - mse: 0.1246
# Epoch 16/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4239 - mse: 0.1245
# Epoch 17/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4237 - mse: 0.1245
# Epoch 18/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4235 - mse: 0.1244
# Epoch 19/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4235 - mse: 0.1245
# Epoch 20/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4235 - mse: 0.1244
# Epoch 21/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4230 - mse: 0.1243
# Epoch 22/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4234 - mse: 0.1244
# Epoch 23/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4229 - mse: 0.1243
# Epoch 24/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4226 - mse: 0.1242
# Epoch 25/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4231 - mse: 0.1243
# Epoch 26/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4231 - mse: 0.1243
# Epoch 27/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4231 - mse: 0.1243
# Epoch 28/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4227 - mse: 0.1242
# Epoch 29/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4231 - mse: 0.1243
# Epoch 30/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4231 - mse: 0.1243
# Epoch 31/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4225 - mse: 0.1242
# Epoch 32/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4226 - mse: 0.1242
# Epoch 33/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4228 - mse: 0.1242
# Epoch 34/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4224 - mse: 0.1242
# Epoch 35/40
# 2129/2129 [==============================] - 3s 2ms/step - loss: 0.4225 - mse: 0.1241
# Epoch 36/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4225 - mse: 0.1242
# Epoch 37/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4226 - mse: 0.1242
# Epoch 38/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4223 - mse: 0.1241
# Epoch 39/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4224 - mse: 0.1241
# Epoch 40/40
# 2129/2129 [==============================] - 3s 1ms/step - loss: 0.4220 - mse: 0.1240
# 666/666 [==============================] - 1s 865us/step
# 666/666 [==============================] - 1s 1ms/step - loss: 0.4223 - mse: 0.1241
# Loss: 0.422294557094574
# Mean Squared Error: 0.12411711364984512
# Shape of predictions: (21283, 1)
# Shape of y_train: (21283,)
# 2/2 [==============================] - 0s 3ms/step
# ************************
#  vancomycin
# Epoch 1/40
# 84/84 [==============================] - 1s 2ms/step - loss: 0.4656 - mse: 0.1470
# Epoch 2/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1805 - mse: 0.0418
# Epoch 3/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1698 - mse: 0.0384
# Epoch 4/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1681 - mse: 0.0376
# Epoch 5/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1631 - mse: 0.0360
# Epoch 6/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1614 - mse: 0.0358
# Epoch 7/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1608 - mse: 0.0352
# Epoch 8/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1599 - mse: 0.0350
# Epoch 9/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1610 - mse: 0.0350
# Epoch 10/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1605 - mse: 0.0352
# Epoch 11/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1606 - mse: 0.0351
# Epoch 12/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1563 - mse: 0.0344
# Epoch 13/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1615 - mse: 0.0355
# Epoch 14/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1603 - mse: 0.0352
# Epoch 15/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1586 - mse: 0.0348
# Epoch 16/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1591 - mse: 0.0349
# Epoch 17/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1599 - mse: 0.0355
# Epoch 18/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1587 - mse: 0.0345
# Epoch 19/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1599 - mse: 0.0347
# Epoch 20/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1571 - mse: 0.0344
# Epoch 21/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1589 - mse: 0.0344
# Epoch 22/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1577 - mse: 0.0345
# Epoch 23/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1578 - mse: 0.0343
# Epoch 24/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1593 - mse: 0.0346
# Epoch 25/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1587 - mse: 0.0345
# Epoch 26/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1579 - mse: 0.0343
# Epoch 27/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1576 - mse: 0.0344
# Epoch 28/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1575 - mse: 0.0343
# Epoch 29/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1565 - mse: 0.0342
# Epoch 30/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1564 - mse: 0.0341
# Epoch 31/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1560 - mse: 0.0343
# Epoch 32/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1576 - mse: 0.0343
# Epoch 33/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1569 - mse: 0.0343
# Epoch 34/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1584 - mse: 0.0346
# Epoch 35/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1573 - mse: 0.0345
# Epoch 36/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1566 - mse: 0.0342
# Epoch 37/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1577 - mse: 0.0343
# Epoch 38/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1564 - mse: 0.0343
# Epoch 39/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.1573 - mse: 0.0343
# Epoch 40/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.1567 - mse: 0.0342
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1544 - mse: 0.0338
# Loss: 0.15440091490745544
# Mean Squared Error: 0.03381878882646561
# Shape of predictions: (838, 1)
# Shape of y_train: (838,)
# 1/1 [==============================] - 0s 17ms/step
# ************************
#  Imipenem-EDTA-PA
# Epoch 1/40
# 9/9 [==============================] - 1s 2ms/step - loss: 0.6931 - mse: 2.6987e-09
# Epoch 2/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.1827e-09
# Epoch 3/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 3.7360e-10
# Epoch 4/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.9691e-10
# Epoch 5/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 6.4520e-11
# Epoch 6/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 2.6239e-11
# Epoch 7/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.1451e-11
# Epoch 8/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 4.9303e-12
# Epoch 9/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 2.1234e-12
# Epoch 10/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 8.4152e-13
# Epoch 11/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 3.3835e-13
# Epoch 12/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 1.2868e-13
# Epoch 13/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 1.0255e-13
# Epoch 14/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.3204e-14
# Epoch 15/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 4.2871e-14
# Epoch 16/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 4.2654e-14
# Epoch 17/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 2.2746e-14
# Epoch 18/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 2.1555e-14
# Epoch 19/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 2.5779e-15
# Epoch 20/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 3.8777e-15
# Epoch 21/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.9085e-14
# Epoch 22/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 3.2711e-15
# Epoch 23/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.8977e-14
# Epoch 24/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 7.1488e-14
# Epoch 25/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.2121e-14
# Epoch 26/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 3.5722e-14
# Epoch 27/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 8.2319e-15
# Epoch 28/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.1503e-14
# Epoch 29/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 3.9231e-14
# Epoch 30/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.5034e-14
# Epoch 31/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.6810e-14
# Epoch 32/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 6.9321e-15
# Epoch 33/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.6269e-14
# Epoch 34/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.2456e-14
# Epoch 35/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 9.2067e-15
# Epoch 36/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 1.2045e-14
# Epoch 37/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 3.3447e-14
# Epoch 38/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 7.1704e-15
# Epoch 39/40
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6931 - mse: 5.8706e-15
# Epoch 40/40
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 2.0818e-14
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6931 - mse: 1.4211e-14
# Loss: 0.6931471824645996
# Mean Squared Error: 1.4210854715202004e-14
# Shape of predictions: (82, 1)
# Shape of y_train: (82,)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


for drug, val_drug in drug_val_dict.items():
    drug_df,drug_genes = gene_per_drug(drug)
    drug_train_for_model = create_update_gene_df(drug_df,list(drug_genes), drug)
    # Step 1: Get selected_values for the current drug
    selected_values = gene_antibiotic_df[drug][(gene_antibiotic_df[drug] != 0) & (gene_antibiotic_df[drug] != -1)]

    # Step 2: Build Y_pred for the current drug
    Y_pred = (selected_values > 0.9).astype(int)

    # Step 3: Build Y_true for the current drug
    Y_true = pd.Series(0, index=Y_pred.index)

    # Set values in Y_true for genes in val_drug['Gene family']
    for gene in Y_pred.index.intersection(val_drug['Gene family']):
            Y_true[gene] = 1

    # Check if there are rows in drug_train_for_model where gene is 1 and label is 0
    for gene in Y_pred.index:
        if Y_true[gene] == 0 and ((drug_train_for_model[gene] == 1) & (drug_train_for_model['label'] == 0)).any():
            Y_true[gene] = 0

    accuracy = accuracy_score(Y_true, Y_pred)
    precision = precision_score(Y_true, Y_pred)
    recall = recall_score(Y_true, Y_pred)
    f1 = f1_score(Y_true, Y_pred)
    print(f"Drug: {drug}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1-score: {f1:.2f}")
    print("\n")
# Out:
# Drug: chloramphenicol
# Accuracy: 0.81
# Precision: 0.40
# Recall: 0.40
# F1-score: 0.40
#
#
# Drug: streptomycin
# Accuracy: 0.69
# Precision: 0.50
# Recall: 0.44
# F1-score: 0.47
#
#
# Drug: azithromycin
# Accuracy: 0.73
# Precision: 0.00
# Recall: 0.00
# F1-score: 0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 23
#      21 # Check if there are rows in drug_train_for_model where gene is 1 and label is 0
#      22 for gene in Y_pred.index:
# ---> 23     if Y_true[gene] == 0 and ((drug_train_for_model[gene] == 1) & (drug_train_for_model['label'] == 0)).any():
#      24         Y_true[gene] = 0
#      26 accuracy = accuracy_score(Y_true, Y_pred)
#
# File ~/PycharmProjects/finalProject_Antibiotic/venv/lib/python3.9/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/PycharmProjects/finalProject_Antibiotic/venv/lib/python3.9/site-packages/pandas/core/arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File ~/PycharmProjects/finalProject_Antibiotic/venv/lib/python3.9/site-packages/pandas/core/series.py:6108, in Series._logical_method(self, other, op)
#    6105 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6107 res_values = ops.logical_op(lvalues, rvalues, op)
# -> 6108 return self._construct_result(res_values, name=res_name)
#
# File ~/PycharmProjects/finalProject_Antibiotic/venv/lib/python3.9/site-packages/pandas/core/series.py:3106, in Series._construct_result(self, result, name)
#    3104 dtype = getattr(result, "dtype", None)
#    3105 out = self._constructor(result, index=self.index, dtype=dtype)
# -> 3106 out = out.__finalize__(self)
#    3108 # Set the result's name after __finalize__ is called because __finalize__
#    3109 #  would set it back to self.name
#    3110 out.name = name
#
# KeyboardInterrupt:

# %%
len(drug_val_dict)
# Out:
# 12

# %%
# drug = 'trimethoprim'
# print('************************\n', drug)
# drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
# drug_df,drug_genes = gene_per_drug(drug)
# drug_train_for_model = create_update_gene_df(drug_df,list(drug_genes), drug)
#
# y_train, predictions, model = Model_deep(drug_train_for_model, 40, 10)
# df_gene = Create_df_one_gene(drug_train_for_model)
# if df_gene.shape[1]>1:
#  pred = model.predict(df_gene)
# else:
#     problematic_drugs.append(drug)
#
# for col in drug_genes:
#     if (df_gene.shape[1]>1) and (col in drug_r):
#      gene_antibiotic_df.loc[col, drug] = pred[df_gene.columns.get_loc(col)]
#     else:
#       gene_antibiotic_df.loc[col, drug] = 0.0
# val_drug= relevant_val_df(drug, drug_genes)
# Out:
# ************************
#  trimethoprim
# {'dfra15', 'dfra20', 'dfrb5', 'dfra17', 'dfra12', 'dfra25', 'type a nfxb', 'dfrk', 'dfra7', 'oprm', 'nalc', 'dfra27', 'dfrb3', 'oqxa', 'opme', 'mexf', 'dfra16', 'oprj', 'dfra21', 'dfra15b', 'oqxb', 'dfra32', 'dfra22', 'aden', 'adej', 'adei', 'adek', 'mexe', 'dfrf', 'dfra19', 'dfra10', 'mexb', 'dfra5', 'mexr', 'dfra26', 'dfra3b', 'dfrd', 'dfrc', 'dfra8', 'mexd', 'oprn', 'dfrg', 'rsma', 'mexq', 'dfrb1', 'dfra14', 'mexp', 'mexa', 'dfre', 'mexc', 'dfra1'}
# Epoch 1/40
# 44/44 [==============================] - 1s 2ms/step - loss: 0.5929 - mse: 0.2034
# Epoch 2/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4492 - mse: 0.1549
# Epoch 3/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3896 - mse: 0.1292
# Epoch 4/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1464 - mse: 0.0338
# Epoch 5/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1134 - mse: 0.0239
# Epoch 6/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1136 - mse: 0.0233
# Epoch 7/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1073 - mse: 0.0230
# Epoch 8/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1068 - mse: 0.0230
# Epoch 9/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1057 - mse: 0.0228
# Epoch 10/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1064 - mse: 0.0228
# Epoch 11/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1069 - mse: 0.0232
# Epoch 12/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1070 - mse: 0.0229
# Epoch 13/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1059 - mse: 0.0228
# Epoch 14/40
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1059 - mse: 0.0231
# Epoch 15/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1082 - mse: 0.0229
# Epoch 16/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1063 - mse: 0.0229
# Epoch 17/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1062 - mse: 0.0228
# Epoch 18/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1056 - mse: 0.0228
# Epoch 19/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1069 - mse: 0.0232
# Epoch 20/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1063 - mse: 0.0229
# Epoch 21/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1077 - mse: 0.0231
# Epoch 22/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1057 - mse: 0.0227
# Epoch 23/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1078 - mse: 0.0235
# Epoch 24/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1073 - mse: 0.0232
# Epoch 25/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1080 - mse: 0.0230
# Epoch 26/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1058 - mse: 0.0230
# Epoch 27/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1072 - mse: 0.0229
# Epoch 28/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1057 - mse: 0.0230
# Epoch 29/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1076 - mse: 0.0230
# Epoch 30/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1074 - mse: 0.0235
# Epoch 31/40
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1088 - mse: 0.0232
# Epoch 32/40
# 44/44 [==============================] - 0s 1ms/step - loss: 0.1058 - mse: 0.0229
# Epoch 33/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1065 - mse: 0.0230
# Epoch 34/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1063 - mse: 0.0228
# Epoch 35/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1069 - mse: 0.0228
# Epoch 36/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1058 - mse: 0.0228
# Epoch 37/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1062 - mse: 0.0228
# Epoch 38/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1078 - mse: 0.0231
# Epoch 39/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1083 - mse: 0.0231
# Epoch 40/40
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1068 - mse: 0.0229
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1042 - mse: 0.0226
# Loss: 0.10417705774307251
# Mean Squared Error: 0.02260635606944561
# Shape of predictions: (435, 1)
# Shape of y_train: (435,)
# 1/1 [==============================] - 0s 19ms/step

# %%
drug = 'vancomycin'
print('************************\n', drug)
drug_r = anti_family.loc[(anti_family['antibiotic'] == drug) & (anti_family['R'] == 1), 'gene'].tolist()
drug_df,drug_genes = gene_per_drug(drug)
drug_train_for_model = create_update_gene_df(drug_df,list(drug_genes), drug)

y_train, predictions, model = Model_deep(drug_train_for_model, 40, 10)
df_gene = Create_df_one_gene(drug_train_for_model)
if df_gene.shape[1]>1:
 pred = model.predict(df_gene)
else:
    problematic_drugs.append(drug)

for col in drug_genes:
    if (df_gene.shape[1]>1) and (col in drug_r):
     gene_antibiotic_df.loc[col, drug] = pred[df_gene.columns.get_loc(col)]
    else:
      gene_antibiotic_df.loc[col, drug] = 0.0
val_drug= relevant_val_df(drug, drug_genes)
# Out:
# ************************
#  vancomycin
# Epoch 1/40
# 84/84 [==============================] - 2s 2ms/step - loss: 0.4125 - mse: 0.1261
# Epoch 2/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0143 - mse: 4.3067e-04
# Epoch 3/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0063 - mse: 1.4291e-05
# Epoch 4/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0056 - mse: 1.3640e-05
# Epoch 5/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 5.6184e-05
# Epoch 6/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0057 - mse: 1.9433e-04
# Epoch 7/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0074 - mse: 6.3807e-04
# Epoch 8/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0070 - mse: 6.0942e-04
# Epoch 9/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0055 - mse: 1.6668e-04
# Epoch 10/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0052 - mse: 4.0826e-05
# Epoch 11/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0051 - mse: 2.6162e-05
# Epoch 12/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0051 - mse: 2.1819e-05
# Epoch 13/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0053 - mse: 1.0435e-04
# Epoch 14/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0055 - mse: 1.9385e-04
# Epoch 15/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0070 - mse: 6.5470e-04
# Epoch 16/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0067 - mse: 3.9539e-04
# Epoch 17/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0054 - mse: 1.4256e-04
# Epoch 18/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0056 - mse: 2.2238e-04
# Epoch 19/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 1.4719e-04
# Epoch 20/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0056 - mse: 2.0828e-04
# Epoch 21/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0057 - mse: 2.7026e-04
# Epoch 22/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0071 - mse: 5.4412e-04
# Epoch 23/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0056 - mse: 2.3572e-04
# Epoch 24/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0062 - mse: 4.1583e-04
# Epoch 25/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0075 - mse: 7.2485e-04
# Epoch 26/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 1.3143e-04
# Epoch 27/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0055 - mse: 1.5908e-04
# Epoch 28/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 4.0759e-06
# Epoch 29/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0050 - mse: 2.3051e-07
# Epoch 30/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 1.9227e-06
# Epoch 31/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0051 - mse: 3.0688e-05
# Epoch 32/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0054 - mse: 1.8297e-04
# Epoch 33/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0051 - mse: 3.5236e-05
# Epoch 34/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0053 - mse: 1.5202e-04
# Epoch 35/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0068 - mse: 6.0090e-04
# Epoch 36/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0058 - mse: 2.7768e-04
# Epoch 37/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 9.4751e-06
# Epoch 38/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 4.5283e-07
# Epoch 39/40
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0050 - mse: 7.5149e-07
# Epoch 40/40
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 2.3243e-05
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 2.0878e-05
# Loss: 0.00503109535202384
# Mean Squared Error: 2.0878225768683478e-05
# Shape of predictions: (838, 1)
# Shape of y_train: (838,)
# 1/1 [==============================] - 0s 70ms/step

# %%
bb = drug_train_for_model
bb.to_csv('vancomycin_drug_train_for_model_alldata.csv')

# %%
aa = gene_antibiotic_df[drug]
aa.to_csv('vancomycin_pred_alldata.csv')

# %%
selected_values = aa[(aa != 0) & (aa != -1)]
filtered_values = selected_values[selected_values.index.isin(val_drug['Gene family'])]
print(selected_values)
# Out:
# vansa     1.273470e-03
# vanza     7.702166e-05
# vana      7.315446e-05
# vanha     1.151233e-05
# oqxa      3.292177e-05
# vanra     3.734033e-03
# vanya     3.461405e-05
# vang      5.102035e-04
# dfra14    3.088594e-05
# vanxa     5.875593e-05
# mexa      1.847483e-04
# dfra17    6.470926e-04
# oqxb      1.198735e-05
# dfrg      3.275530e-07
# dfrf      9.418059e-06
# dfra12    2.998570e-04
# dfrc      7.494794e-06
# dfra10    2.140212e-06
# dfre      9.474148e-07
# dfra1     1.144084e-04
# mexe      5.633589e-05
# Name: vancomycin, dtype: float64

# %%
print(val_drug)
# Out:
#     Gene family    Subclass
# 544        vana  vancomycin
# 556        vang  vancomycin
# 557       vanha  vancomycin
# 575       vanra  vancomycin
# 586       vansa  vancomycin
# 608       vanxa  vancomycin
# 625       vanya  vancomycin
# 632       vanza  vancomycin

# %%
print(selected_values)
# Out:
# dfra5     0.999809
# dfra7     0.999440
# oqxa      0.027315
# dfra27    0.737019
# dfra14    0.999170
# dfra16    0.998257
# dfra17    0.999921
# oqxb      0.032517
# dfrg      0.998768
# dfra8     0.998096
# dfra12    0.999917
# dfra1     0.999950
# Name: trimethoprim, dtype: float64

# %%
print(val_drug)
# Out:
#     Gene family      Subclass
# 306       dfra1  trimethoprim
# 308      dfra12  trimethoprim
# 309      dfra14  trimethoprim
# 311      dfra16  trimethoprim
# 312      dfra17  trimethoprim
# 317      dfra23  trimethoprim
# 321      dfra27  trimethoprim
# 327       dfra5  trimethoprim
# 330       dfra7  trimethoprim
# 331       dfra8  trimethoprim
# 338        dfrg  trimethoprim
# 842      dfra36  trimethoprim

# %%
Y_pred
# Out:
# dfra5     1
# dfra7     1
# oqxa      0
# dfra27    0
# dfra14    1
# dfra16    1
# dfra17    1
# oqxb      0
# dfrg      1
# dfra8     1
# dfra12    1
# dfra1     1
# Name: trimethoprim, dtype: int64

# %%
print(Y_true)
# Out:
# dfra5     1
# dfra7     1
# oqxa      0
# dfra27    1
# dfra14    1
# dfra16    1
# dfra17    1
# oqxb      0
# dfrg      1
# dfra8     1
# dfra12    1
# dfra1     1
# dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y_true, Y_pred)
precision = precision_score(Y_true, Y_pred)
recall = recall_score(Y_true, Y_pred)
f1 = f1_score(Y_true, Y_pred)
print(f"Drug: {drug}")
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
print("\n")
# Out:
# Drug: trimethoprim
# Accuracy: 0.92
# Precision: 1.00
# Recall: 0.90
# F1-score: 0.95

# %%
# strep_pred = gene_antibiotic_df[drug]
# # strep_pred.to_csv('trimethoprim_pred_alldata.csv')
# selected_values = strep_pred[(strep_pred != 0) & (strep_pred != -1)]
# filtered_values = selected_values[selected_values.index.isin(val_drug['Gene family'])]
# print(selected_values)
# Out:
# aada2       0.940633
# aph3iib     0.180771
# ant3iia     0.000004
# aph3vi      0.142157
# dfrc        0.078080
# aac3iia     0.996165
# aph4ia      0.745322
# aac6ib3     0.429344
# dfra16      0.999893
# aada22      0.999999
# aac6ib      0.489577
# mexe        0.188463
# aac3iie     0.267240
# mexx        0.216684
# dfra15      0.999996
# aac6ib4     0.913355
# aac3id      0.999726
# rmtc        0.429936
# mexa        0.135967
# aac3iv      0.787854
# aph6id      0.362423
# dfra8       0.041253
# oqxb        0.000843
# aph3iiia    0.559045
# aac3via     0.891152
# aada12      0.999971
# ant2ia      0.023482
# aac2iia     0.000008
# aada6       0.998862
# oqxa        0.407336
# aada15      0.999866
# aph6ic      0.020294
# dfra17      0.067657
# aac6ibcr    0.065812
# aph3iia     0.010021
# aph3ia      0.053150
# dfra27      0.340501
# aada16      0.518817
# dfrg        0.540301
# arma        0.378146
# aada25      0.987919
# aac3iid     0.663348
# aph3ib      0.626161
# dfra1       0.434153
# ant6ia      0.445780
# dfrf        0.000031
# dfrb3       0.000076
# ant9ia      0.495526
# dfra7       0.999054
# aada5       0.065084
# dfra5       0.000457
# dfra14      0.240809
# aada4       0.999978
# aac6iic     0.999430
# dfra19      0.991192
# aada7       0.199449
# aada13      0.999677
# dfra12      0.021534
# Name: streptomycin, dtype: float64

# %%
# print(len(filtered_values))
# print(len(val_drug))
# Out:
# 18
# 20

# %%
len(problematic_drugs)
# Out:
# 35

# %%
# Load the original DataFrame from "BasicData.csv"
original_df = pd.read_csv("BasicData.csv")

# Create a copy of gene_antibiotic_df
gene_antibiotic_df_copy = gene_antibiotic_df.copy()

# Get the list of genes from original_df['AMR genotypes'] by splitting with ", "
original_genes = original_df['AMR genotypes'].str.split(", ")

# Get the list of genes from df['AMR genotypes'] by splitting with ", "
cleaned_genes = df['AMR genotypes'].str.split(", ")

# Create a mapping dictionary for cleaned gene names to original gene names
gene_mapping = dict(zip(cleaned_genes.explode(), original_genes.explode()))

# Replace the index of gene_antibiotic_df_copy with original gene names based on the mapping
gene_antibiotic_df_copy.index = gene_antibiotic_df_copy.index.map(gene_mapping)

# Save the updated gene_antibiotic_df_copy with original gene names
# gene_antibiotic_df_copy.to_csv("GeneAntibioticData.csv", index=True)
gene_antibiotic_df_copy.head(10)
# Out:
#                levofloxacin  oxacillin  aztreonam  ceftiofur  \
# blaOXA-493             -1.0         -1       -1.0       -1.0
# catA1                   0.0          0        0.0        0.0
# blaIMP-18               0.0         -1        0.0       -1.0
# blaHMB                  0.0         -1        0.0       -1.0
# blaOXA-623             -1.0         -1       -1.0       -1.0
# qnrS                    0.0         -1        0.0       -1.0
# oqxB14                  0.0         -1        0.0       -1.0
# gyrA_E87G               0.0         -1       -1.0       -1.0
# blaCMY-42               0.0         -1        0.0       -1.0
# oprD_Q142STOP           0.0         -1        0.0       -1.0
#
#                cefotaxime-clavulanic acid  meropenem  cefalexin  \
# blaOXA-493                             -1       -1.0         -1
# catA1                                   0        0.0         -1
# blaIMP-18                               0        0.0         -1
# blaHMB                                 -1        0.0         -1
# blaOXA-623                             -1       -1.0         -1
# qnrS                                    0        0.0         -1
# oqxB14                                 -1        0.0         -1
# gyrA_E87G                              -1       -1.0         -1
# blaCMY-42                              -1        0.0         -1
# oprD_Q142STOP                          -1        0.0         -1
#
#                benzylpenicillin  oxytetracycline  mupirocin  ...  rifampin  \
# blaOXA-493                   -1               -1         -1  ...      -1.0
# catA1                        -1               -1         -1  ...       0.0
# blaIMP-18                    -1               -1         -1  ...      -1.0
# blaHMB                       -1               -1         -1  ...      -1.0
# blaOXA-623                   -1               -1         -1  ...      -1.0
# qnrS                         -1               -1         -1  ...      -1.0
# oqxB14                       -1               -1         -1  ...      -1.0
# gyrA_E87G                    -1               -1         -1  ...       0.0
# blaCMY-42                    -1               -1         -1  ...      -1.0
# oprD_Q142STOP                -1               -1         -1  ...      -1.0
#
#                streptomycin  synercid  ceftolozane-tazobactam  sulfonamide  \
# blaOXA-493             -1.0      -1.0                      -1           -1
# catA1                   0.0      -1.0                       0           -1
# blaIMP-18              -1.0      -1.0                       0           -1
# blaHMB                 -1.0      -1.0                       0           -1
# blaOXA-623             -1.0      -1.0                      -1           -1
# qnrS                    0.0      -1.0                       0           -1
# oqxB14                 -1.0      -1.0                       0           -1
# gyrA_E87G              -1.0      -1.0                      -1           -1
# blaCMY-42              -1.0      -1.0                       0           -1
# oprD_Q142STOP          -1.0      -1.0                      -1           -1
#
#                imipenem-relebactam  fusidic acid  amoxicillin-clavulanic acid  \
# blaOXA-493                      -1            -1                           -1
# catA1                           -1            -1                            0
# blaIMP-18                       -1            -1                           -1
# blaHMB                          -1            -1                           -1
# blaOXA-623                      -1            -1                           -1
# qnrS                            -1            -1                            0
# oqxB14                          -1            -1                            0
# gyrA_E87G                       -1            -1                           -1
# blaCMY-42                       -1            -1                            0
# oprD_Q142STOP                   -1            -1                           -1
#
#                quinupristin-dalfopristin  doxycycline
# blaOXA-493                            -1         -1.0
# catA1                                 -1          0.0
# blaIMP-18                             -1         -1.0
# blaHMB                                -1         -1.0
# blaOXA-623                            -1         -1.0
# qnrS                                  -1         -1.0
# oqxB14                                -1         -1.0
# gyrA_E87G                             -1          0.0
# blaCMY-42                             -1         -1.0
# oprD_Q142STOP                         -1         -1.0
#
# [10 rows x 114 columns]

# %%
gene_antibiotic_df.head(10)
# Out:
#               levofloxacin  oxacillin  aztreonam  ceftiofur  \
# blaoxa493             -1.0         -1       -1.0       -1.0
# cata1                  0.0          0        0.0        0.0
# blaimp18               0.0         -1        0.0       -1.0
# blahmb                 0.0         -1        0.0       -1.0
# blaoxa623             -1.0         -1       -1.0       -1.0
# qnrs                   0.0         -1        0.0       -1.0
# oqxb14                 0.0         -1        0.0       -1.0
# gyrae87g               0.0         -1       -1.0       -1.0
# blacmy42               0.0         -1        0.0       -1.0
# oprdq142stop           0.0         -1        0.0       -1.0
#
#               cefotaxime-clavulanic acid  meropenem  cefalexin  \
# blaoxa493                             -1       -1.0         -1
# cata1                                  0        0.0         -1
# blaimp18                               0        0.0         -1
# blahmb                                -1        0.0         -1
# blaoxa623                             -1       -1.0         -1
# qnrs                                   0        0.0         -1
# oqxb14                                -1        0.0         -1
# gyrae87g                              -1       -1.0         -1
# blacmy42                              -1        0.0         -1
# oprdq142stop                          -1        0.0         -1
#
#               benzylpenicillin  oxytetracycline  mupirocin  ...  rifampin  \
# blaoxa493                   -1               -1         -1  ...      -1.0
# cata1                       -1               -1         -1  ...       0.0
# blaimp18                    -1               -1         -1  ...      -1.0
# blahmb                      -1               -1         -1  ...      -1.0
# blaoxa623                   -1               -1         -1  ...      -1.0
# qnrs                        -1               -1         -1  ...      -1.0
# oqxb14                      -1               -1         -1  ...      -1.0
# gyrae87g                    -1               -1         -1  ...       0.0
# blacmy42                    -1               -1         -1  ...      -1.0
# oprdq142stop                -1               -1         -1  ...      -1.0
#
#               streptomycin  synercid  ceftolozane-tazobactam  sulfonamide  \
# blaoxa493             -1.0      -1.0                      -1           -1
# cata1                  0.0      -1.0                       0           -1
# blaimp18              -1.0      -1.0                       0           -1
# blahmb                -1.0      -1.0                       0           -1
# blaoxa623             -1.0      -1.0                      -1           -1
# qnrs                   0.0      -1.0                       0           -1
# oqxb14                -1.0      -1.0                       0           -1
# gyrae87g              -1.0      -1.0                      -1           -1
# blacmy42              -1.0      -1.0                       0           -1
# oprdq142stop          -1.0      -1.0                      -1           -1
#
#               imipenem-relebactam  fusidic acid  amoxicillin-clavulanic acid  \
# blaoxa493                      -1            -1                           -1
# cata1                          -1            -1                            0
# blaimp18                       -1            -1                           -1
# blahmb                         -1            -1                           -1
# blaoxa623                      -1            -1                           -1
# qnrs                           -1            -1                            0
# oqxb14                         -1            -1                            0
# gyrae87g                       -1            -1                           -1
# blacmy42                       -1            -1                            0
# oprdq142stop                   -1            -1                           -1
#
#               quinupristin-dalfopristin  doxycycline
# blaoxa493                            -1         -1.0
# cata1                                -1          0.0
# blaimp18                             -1         -1.0
# blahmb                               -1         -1.0
# blaoxa623                            -1         -1.0
# qnrs                                 -1         -1.0
# oqxb14                               -1         -1.0
# gyrae87g                             -1          0.0
# blacmy42                             -1         -1.0
# oprdq142stop                         -1         -1.0
#
# [10 rows x 114 columns]

# %%
gene_antibiotic_df_copy.shape
# Out:
# (1209, 114)

# %%
gene_antibiotic_df_copy = gene_antibiotic_df_copy.loc[:, (gene_antibiotic_df_copy != -1.0).any(axis=0)]
gene_antibiotic_df_copy.shape
# Out:
# (1209, 72)

# %%
gene_antibiotic_df_copy.head(10)
# Out:
#                levofloxacin  oxacillin  aztreonam  ceftiofur  \
# blaOXA-493             -1.0         -1       -1.0       -1.0
# catA1                   0.0          0        0.0        0.0
# blaIMP-18               0.0         -1        0.0       -1.0
# blaHMB                  0.0         -1        0.0       -1.0
# blaOXA-623             -1.0         -1       -1.0       -1.0
# qnrS                    0.0         -1        0.0       -1.0
# oqxB14                  0.0         -1        0.0       -1.0
# gyrA_E87G               0.0         -1       -1.0       -1.0
# blaCMY-42               0.0         -1        0.0       -1.0
# oprD_Q142STOP           0.0         -1        0.0       -1.0
#
#                cefotaxime-clavulanic acid  meropenem  mupirocin  \
# blaOXA-493                             -1       -1.0         -1
# catA1                                   0        0.0         -1
# blaIMP-18                               0        0.0         -1
# blaHMB                                 -1        0.0         -1
# blaOXA-623                             -1       -1.0         -1
# qnrS                                    0        0.0         -1
# oqxB14                                 -1        0.0         -1
# gyrA_E87G                              -1       -1.0         -1
# blaCMY-42                              -1        0.0         -1
# oprD_Q142STOP                          -1        0.0         -1
#
#                ciprofloxacin  clindamycin  cefpodoxime  ...  telithromycin  \
# blaOXA-493               0.0          0.0           -1  ...              0
# catA1                    0.0         -1.0            0  ...             -1
# blaIMP-18                0.0         -1.0           -1  ...             -1
# blaHMB                   0.0         -1.0           -1  ...             -1
# blaOXA-623               0.0          0.0           -1  ...              0
# qnrS                     0.0         -1.0            0  ...             -1
# oqxB14                   0.0         -1.0            0  ...             -1
# gyrA_E87G               -1.0         -1.0           -1  ...             -1
# blaCMY-42                0.0         -1.0           -1  ...             -1
# oprD_Q142STOP            0.0         -1.0           -1  ...             -1
#
#                piperacillin-tazobactam  cephalothin  rifampin  streptomycin  \
# blaOXA-493                          -1           -1      -1.0          -1.0
# catA1                                0            0       0.0           0.0
# blaIMP-18                            0           -1      -1.0          -1.0
# blaHMB                               0           -1      -1.0          -1.0
# blaOXA-623                          -1           -1      -1.0          -1.0
# qnrS                                 0            0      -1.0           0.0
# oqxB14                               0            0      -1.0          -1.0
# gyrA_E87G                           -1           -1       0.0          -1.0
# blaCMY-42                            0           -1      -1.0          -1.0
# oprD_Q142STOP                        0           -1      -1.0          -1.0
#
#                synercid  ceftolozane-tazobactam  fusidic acid  \
# blaOXA-493         -1.0                      -1            -1
# catA1              -1.0                       0            -1
# blaIMP-18          -1.0                       0            -1
# blaHMB             -1.0                       0            -1
# blaOXA-623         -1.0                      -1            -1
# qnrS               -1.0                       0            -1
# oqxB14             -1.0                       0            -1
# gyrA_E87G          -1.0                      -1            -1
# blaCMY-42          -1.0                       0            -1
# oprD_Q142STOP      -1.0                      -1            -1
#
#                amoxicillin-clavulanic acid  doxycycline
# blaOXA-493                              -1         -1.0
# catA1                                    0          0.0
# blaIMP-18                               -1         -1.0
# blaHMB                                  -1         -1.0
# blaOXA-623                              -1         -1.0
# qnrS                                     0         -1.0
# oqxB14                                   0         -1.0
# gyrA_E87G                               -1          0.0
# blaCMY-42                                0         -1.0
# oprD_Q142STOP                           -1         -1.0
#
# [10 rows x 72 columns]

# %%
gene_antibiotic_df_copy.to_csv("results_19_07.csv",index=True, index_label=False)
